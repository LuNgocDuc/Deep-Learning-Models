# %% [markdown]
# # Import thư viện cần thiết

# %%
#bỏ qua các cảnh báo
import warnings
warnings.filterwarnings('ignore')
#thư viện toán học cho hàm toán học
import math
#dùng để đọc dữ liệu
import pandas as pd
#giúp xử lý số liệu
import numpy as np
#dùng để chuẩn hóa dữ liệu
from sklearn.preprocessing import MinMaxScaler
#cài keras - thư viện mạng thần kinh for LSTM
from keras.layers import LSTM
from keras.layers import Dense
from keras.models import Sequential
#dùng để vẽ biểu đồ 
import matplotlib.pyplot as mtlplt
mtlplt.style.use("fivethirtyeight")
# %matplotlib inline
from matplotlib import rcParams 
import tkinter
from matplotlib.backends.backend_tkagg import (
    FigureCanvasTkAgg, NavigationToolbar2Tk)

# %%
AAPL = pd.read_csv("./Database/Pre_Processed_AAPL.csv")

# %% [markdown]
# # Lấy data từ file

# %%
file = './Database/Pre_Processed_AAPL.csv' #dữ liệu được tải về từ trang tradingview.com được niêm yết trên thị trường chứng khoán VN
df = pd.read_csv(file,parse_dates=True,index_col=0)
data = df.reset_index('Date') #đặt cột Date làm chỉ mục
data
# Out:
#            Date    Open    High     Low   Close  Adj. Close       Volume
# 0    2015-01-02   27.85   27.86   26.84   27.33       24.86  212818400.0
# 1    2015-01-05   27.07   27.16   26.35   26.56       24.16  257142000.0
# 2    2015-01-06   26.64   26.86   26.16   26.57       24.16  263188400.0
# 3    2015-01-07   26.80   27.05   26.67   26.94       24.50  160423600.0
# 4    2015-01-08   27.31   28.04   27.17   27.97       25.44  237458000.0
# ...         ...     ...     ...     ...     ...         ...          ...
# 1544 2021-02-22  128.01  129.72  125.60  126.00      126.00  103607600.0
# 1545 2021-02-23  123.76  126.71  118.39  125.86      125.86  157859100.0
# 1546 2021-02-24  124.94  125.56  122.23  125.35      125.35  110691500.0
# 1547 2021-02-25  124.68  126.46  120.54  120.99      120.99  147306500.0
# 1548 2021-02-26  122.59  124.85  121.20  121.26      121.26  164320000.0
#
# [1549 rows x 7 columns]

# %% [markdown]
# # Lấy số lượng cột và hàng

# %%
df.shape
# Out:
# (1549, 6)

# %% [markdown]
# # Vẽ biểu đồ từ dữ liệu

# %%
#Đây là biểu đồ giá đóng cửa của data từ khoảng thời gian 1/4/2016 đến 10/1/2022
mtlplt.figure(figsize=(18,9))
mtlplt.title('Close price history data')
mtlplt.plot(df['Close']) 
mtlplt.xlabel('Date', fontsize=20) #trục x biễu diễn cột Date
mtlplt.ylabel('Close price in $(VND)',fontsize=20) #trục y biểu diễn giá đóng trong ngày
mtlplt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Tiền xử lý tập dữ liệu

# %%
#Tạo dataframe chỉ có cột giá đóng
stock_close_data = df.filter(['Close'])

#chuyển đổi dataframe đã tạo thành mảng numpy bằng hàm values
stock_close_dataset = stock_close_data.values

#chia dữ liệu thành tập train and test(train chiếm 80% data và test 20% còn lại của data)
trainingDataLength = math.ceil( len(stock_close_dataset) * 0.8 )

#hiển thị độ dài tập trai
trainingDataLength
# Out:
# 1240

# %%
#Scale dữ liệu về dạng 0,1 giúp model train nhanh hơn. 
#Lstm hoạt động tốt hơn khi các giá trị đầu vào được chia tỷ lệ thành phạm vi tiêu chuẩn
scaler = MinMaxScaler(feature_range=(0,1))

#tiến hành scale dữ liệu bằng fit.trainsform
scaledData = scaler.fit_transform(stock_close_dataset)

#hiển thị giá trị dữ liệu được chia
scaledData.shape
# Out:
# (1549, 1)

# %%
#tạo tập dữ liệu mới chứa giá trị giá trị scale có kích thước từ 0 đến kích thươc dữ liệu 80% ở trên
StockTrainData = scaledData[0:trainingDataLength , :]

#tách dữ liệu thành 2 phần Xtrain và Ytrain
Xtrain = []
Ytrain = []
#tiến hành tạo dữ lieu cho xtrain và ytrain bằng vòng lặp trong phạm vi từ 60 đến tổng kích thước dữ liệu huấn luyện
#tạo dữ liệu với timestep=60 ngày, xem xét dữ liệu quá khứ để đoán ra ngày 61 
for i in range(60, len(StockTrainData)):
  Xtrain.append(StockTrainData[i-60:i, 0])
  Ytrain.append(StockTrainData[i, 0])
  if i<= 61:
    print(Xtrain)
    print(Ytrain)
    print()
# Out:
# [array([0.03939293, 0.03300713, 0.03309006, 0.03615857, 0.04470061,
#        0.04494941, 0.03922707, 0.04130038, 0.04038812, 0.03416819,
#        0.03250954, 0.03814895, 0.03989053, 0.04577874, 0.04702272,
#        0.04718859, 0.03897827, 0.05183281, 0.05929673, 0.0556477 ,
#        0.05871621, 0.05871621, 0.06062365, 0.06145298, 0.05929673,
#        0.06095538, 0.06568253, 0.07165367, 0.07488804, 0.07621496,
#        0.07779068, 0.07961519, 0.07903467, 0.08127384, 0.08848897,
#        0.08674739, 0.07978106, 0.08309836, 0.0791176 , 0.08036159,
#        0.08094211, 0.07920053, 0.07480511, 0.07521977, 0.07629789,
#        0.07090728, 0.06618013, 0.07074142, 0.06899983, 0.07181954,
#        0.07613203, 0.0791176 , 0.07712722, 0.07380992, 0.07646376,
#        0.07538564, 0.06850224, 0.07032675, 0.06825344, 0.07472218])]
# [0.0707414164869796]
#
# [array([0.03939293, 0.03300713, 0.03309006, 0.03615857, 0.04470061,
#        0.04494941, 0.03922707, 0.04130038, 0.04038812, 0.03416819,
#        0.03250954, 0.03814895, 0.03989053, 0.04577874, 0.04702272,
#        0.04718859, 0.03897827, 0.05183281, 0.05929673, 0.0556477 ,
#        0.05871621, 0.05871621, 0.06062365, 0.06145298, 0.05929673,
#        0.06095538, 0.06568253, 0.07165367, 0.07488804, 0.07621496,
#        0.07779068, 0.07961519, 0.07903467, 0.08127384, 0.08848897,
#        0.08674739, 0.07978106, 0.08309836, 0.0791176 , 0.08036159,
#        0.08094211, 0.07920053, 0.07480511, 0.07521977, 0.07629789,
#        0.07090728, 0.06618013, 0.07074142, 0.06899983, 0.07181954,
#        0.07613203, 0.0791176 , 0.07712722, 0.07380992, 0.07646376,
#        0.07538564, 0.06850224, 0.07032675, 0.06825344, 0.07472218]), array([0.03300713, 0.03309006, 0.03615857, 0.04470061, 0.04494941,
#        0.03922707, 0.04130038, 0.04038812, 0.03416819, 0.03250954,
#        0.03814895, 0.03989053, 0.04577874, 0.04702272, 0.04718859,
#        0.03897827, 0.05183281, 0.05929673, 0.0556477 , 0.05871621,
#        0.05871621, 0.06062365, 0.06145298, 0.05929673, 0.06095538,
#        0.06568253, 0.07165367, 0.07488804, 0.07621496, 0.07779068,
#        0.07961519, 0.07903467, 0.08127384, 0.08848897, 0.08674739,
#        0.07978106, 0.08309836, 0.0791176 , 0.08036159, 0.08094211,
#        0.07920053, 0.07480511, 0.07521977, 0.07629789, 0.07090728,
#        0.06618013, 0.07074142, 0.06899983, 0.07181954, 0.07613203,
#        0.0791176 , 0.07712722, 0.07380992, 0.07646376, 0.07538564,
#        0.06850224, 0.07032675, 0.06825344, 0.07472218, 0.07074142])]
# [0.0707414164869796, 0.0703267540222259]

# %%
#chuyển đổi dữ liệu Xtrain, dữ liệu Ytrain thành mảng numpy 
Xtrain = np.array(Xtrain)
Ytrain = np.array(Ytrain)

# %%
#định hình lại dữ liệu Xtrain cho phù hợp với dữ liệu đầu vào thành dạng 3D và 1 đối tượng đại diện giá đóng cửa
Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], Xtrain.shape[1], 1))
Xtrain.shape
# Out:
# (1180, 60, 1)

# %% [markdown]
# # Tạo model và xây dựng mô hình LSTM

# %%
#khởi tạo model
model = Sequential()

neurons = 50

#lớp LSTM đầu
model.add(LSTM(neurons, return_sequences=True, input_shape= (Xtrain.shape[1], 1))) 

#lớp LSTM thứ 2, không còn lớp nào cho lstm nên return_sequences= False
model.add(LSTM(neurons, return_sequences= False)) 

#thêm lớp nơron dày đặc
model.add(Dense(25)) 
model.add(Dense(1))

# %%
#biên dịch model
model.compile(optimizer='adam', loss='mse')

# %%
#đào tạo với tập Xtrain, Ytrain đã cho
history_data = model.fit(Xtrain, Ytrain, batch_size=50, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# 24/24 - 4s - loss: 0.0037 - 4s/epoch - 184ms/step
# Epoch 2/200
# 24/24 - 1s - loss: 2.9129e-04 - 602ms/epoch - 25ms/step
# Epoch 3/200
# 24/24 - 1s - loss: 1.6127e-04 - 617ms/epoch - 26ms/step
# Epoch 4/200
# 24/24 - 1s - loss: 1.4734e-04 - 585ms/epoch - 24ms/step
# Epoch 5/200
# 24/24 - 1s - loss: 1.4183e-04 - 606ms/epoch - 25ms/step
# Epoch 6/200
# 24/24 - 1s - loss: 1.3895e-04 - 632ms/epoch - 26ms/step
# Epoch 7/200
# 24/24 - 1s - loss: 1.2972e-04 - 584ms/epoch - 24ms/step
# Epoch 8/200
# 24/24 - 1s - loss: 1.2426e-04 - 628ms/epoch - 26ms/step
# Epoch 9/200
# 24/24 - 1s - loss: 1.2156e-04 - 583ms/epoch - 24ms/step
# Epoch 10/200
# 24/24 - 1s - loss: 1.2088e-04 - 601ms/epoch - 25ms/step
# Epoch 11/200
# 24/24 - 1s - loss: 1.1866e-04 - 579ms/epoch - 24ms/step
# Epoch 12/200
# 24/24 - 1s - loss: 1.0566e-04 - 586ms/epoch - 24ms/step
# Epoch 13/200
# 24/24 - 1s - loss: 1.0440e-04 - 602ms/epoch - 25ms/step
# Epoch 14/200
# 24/24 - 1s - loss: 1.0536e-04 - 586ms/epoch - 24ms/step
# Epoch 15/200
# 24/24 - 1s - loss: 1.0509e-04 - 601ms/epoch - 25ms/step
# Epoch 16/200
# 24/24 - 1s - loss: 9.9458e-05 - 602ms/epoch - 25ms/step
# Epoch 17/200
# 24/24 - 1s - loss: 1.0518e-04 - 601ms/epoch - 25ms/step
# Epoch 18/200
# 24/24 - 1s - loss: 9.0035e-05 - 585ms/epoch - 24ms/step
# Epoch 19/200
# 24/24 - 1s - loss: 8.6981e-05 - 586ms/epoch - 24ms/step
# Epoch 20/200
# 24/24 - 1s - loss: 9.4121e-05 - 602ms/epoch - 25ms/step
# Epoch 21/200
# 24/24 - 1s - loss: 9.9336e-05 - 586ms/epoch - 24ms/step
# Epoch 22/200
# 24/24 - 1s - loss: 8.5811e-05 - 601ms/epoch - 25ms/step
# Epoch 23/200
# 24/24 - 1s - loss: 8.4659e-05 - 594ms/epoch - 25ms/step
# Epoch 24/200
# 24/24 - 1s - loss: 8.2700e-05 - 601ms/epoch - 25ms/step
# Epoch 25/200
# 24/24 - 1s - loss: 8.1267e-05 - 600ms/epoch - 25ms/step
# Epoch 26/200
# 24/24 - 1s - loss: 9.0930e-05 - 602ms/epoch - 25ms/step
# Epoch 27/200
# 24/24 - 1s - loss: 9.4200e-05 - 586ms/epoch - 24ms/step
# Epoch 28/200
# 24/24 - 1s - loss: 8.1383e-05 - 602ms/epoch - 25ms/step
# Epoch 29/200
# 24/24 - 1s - loss: 8.0921e-05 - 602ms/epoch - 25ms/step
# Epoch 30/200
# 24/24 - 1s - loss: 7.7570e-05 - 586ms/epoch - 24ms/step
# Epoch 31/200
# 24/24 - 1s - loss: 7.9278e-05 - 595ms/epoch - 25ms/step
# Epoch 32/200
# 24/24 - 1s - loss: 7.6520e-05 - 586ms/epoch - 24ms/step
# Epoch 33/200
# 24/24 - 1s - loss: 7.5369e-05 - 586ms/epoch - 24ms/step
# Epoch 34/200
# 24/24 - 1s - loss: 7.4240e-05 - 586ms/epoch - 24ms/step
# Epoch 35/200
# 24/24 - 1s - loss: 8.3288e-05 - 586ms/epoch - 24ms/step
# Epoch 36/200
# 24/24 - 1s - loss: 7.4887e-05 - 586ms/epoch - 24ms/step
# Epoch 37/200
# 24/24 - 1s - loss: 7.0676e-05 - 586ms/epoch - 24ms/step
# Epoch 38/200
# 24/24 - 1s - loss: 7.6993e-05 - 595ms/epoch - 25ms/step
# Epoch 39/200
# 24/24 - 1s - loss: 6.9939e-05 - 586ms/epoch - 24ms/step
# Epoch 40/200
# 24/24 - 1s - loss: 7.4804e-05 - 570ms/epoch - 24ms/step
# Epoch 41/200
# 24/24 - 1s - loss: 6.6515e-05 - 586ms/epoch - 24ms/step
# Epoch 42/200
# 24/24 - 1s - loss: 6.4710e-05 - 601ms/epoch - 25ms/step
# Epoch 43/200
# 24/24 - 1s - loss: 6.4232e-05 - 601ms/epoch - 25ms/step
# Epoch 44/200
# 24/24 - 1s - loss: 6.6169e-05 - 586ms/epoch - 24ms/step
# Epoch 45/200
# 24/24 - 1s - loss: 6.3092e-05 - 601ms/epoch - 25ms/step
# Epoch 46/200
# 24/24 - 1s - loss: 6.3845e-05 - 601ms/epoch - 25ms/step
# Epoch 47/200
# 24/24 - 1s - loss: 6.3909e-05 - 602ms/epoch - 25ms/step
# Epoch 48/200
# 24/24 - 1s - loss: 6.8501e-05 - 586ms/epoch - 24ms/step
# Epoch 49/200
# 24/24 - 1s - loss: 6.1489e-05 - 586ms/epoch - 24ms/step
# Epoch 50/200
# 24/24 - 1s - loss: 6.0313e-05 - 579ms/epoch - 24ms/step
# Epoch 51/200
# 24/24 - 1s - loss: 6.1405e-05 - 585ms/epoch - 24ms/step
# Epoch 52/200
# 24/24 - 1s - loss: 6.2474e-05 - 586ms/epoch - 24ms/step
# Epoch 53/200
# 24/24 - 1s - loss: 7.3589e-05 - 570ms/epoch - 24ms/step
# Epoch 54/200
# 24/24 - 1s - loss: 7.4413e-05 - 601ms/epoch - 25ms/step
# Epoch 55/200
# 24/24 - 1s - loss: 6.1363e-05 - 585ms/epoch - 24ms/step
# Epoch 56/200
# 24/24 - 1s - loss: 6.1764e-05 - 586ms/epoch - 24ms/step
# Epoch 57/200
# 24/24 - 1s - loss: 5.4392e-05 - 595ms/epoch - 25ms/step
# Epoch 58/200
# 24/24 - 1s - loss: 5.6199e-05 - 579ms/epoch - 24ms/step
# Epoch 59/200
# 24/24 - 1s - loss: 5.6064e-05 - 585ms/epoch - 24ms/step
# Epoch 60/200
# 24/24 - 1s - loss: 5.2080e-05 - 602ms/epoch - 25ms/step
# Epoch 61/200
# 24/24 - 1s - loss: 5.2972e-05 - 570ms/epoch - 24ms/step
# Epoch 62/200
# 24/24 - 1s - loss: 5.1167e-05 - 602ms/epoch - 25ms/step
# Epoch 63/200
# 24/24 - 1s - loss: 4.8434e-05 - 586ms/epoch - 24ms/step
# Epoch 64/200
# 24/24 - 1s - loss: 4.8440e-05 - 602ms/epoch - 25ms/step
# Epoch 65/200
# 24/24 - 1s - loss: 4.8660e-05 - 586ms/epoch - 24ms/step
# Epoch 66/200
# 24/24 - 1s - loss: 4.7641e-05 - 602ms/epoch - 25ms/step
# Epoch 67/200
# 24/24 - 1s - loss: 5.2143e-05 - 594ms/epoch - 25ms/step
# Epoch 68/200
# 24/24 - 1s - loss: 4.6435e-05 - 601ms/epoch - 25ms/step
# Epoch 69/200
# 24/24 - 1s - loss: 4.6276e-05 - 602ms/epoch - 25ms/step
# Epoch 70/200
# 24/24 - 1s - loss: 4.7379e-05 - 586ms/epoch - 24ms/step
# Epoch 71/200
# 24/24 - 1s - loss: 4.7628e-05 - 601ms/epoch - 25ms/step
# Epoch 72/200
# 24/24 - 1s - loss: 4.9244e-05 - 586ms/epoch - 24ms/step
# Epoch 73/200
# 24/24 - 1s - loss: 4.7233e-05 - 617ms/epoch - 26ms/step
# Epoch 74/200
# 24/24 - 1s - loss: 4.7789e-05 - 648ms/epoch - 27ms/step
# Epoch 75/200
# 24/24 - 1s - loss: 4.6710e-05 - 639ms/epoch - 27ms/step
# Epoch 76/200
# 24/24 - 1s - loss: 4.2891e-05 - 617ms/epoch - 26ms/step
# Epoch 77/200
# 24/24 - 1s - loss: 4.4720e-05 - 617ms/epoch - 26ms/step
# Epoch 78/200
# 24/24 - 1s - loss: 4.3709e-05 - 617ms/epoch - 26ms/step
# Epoch 79/200
# 24/24 - 1s - loss: 4.1066e-05 - 612ms/epoch - 25ms/step
# Epoch 80/200
# 24/24 - 1s - loss: 4.3143e-05 - 617ms/epoch - 26ms/step
# Epoch 81/200
# 24/24 - 1s - loss: 5.1886e-05 - 593ms/epoch - 25ms/step
# Epoch 82/200
# 24/24 - 1s - loss: 5.3034e-05 - 586ms/epoch - 24ms/step
# Epoch 83/200
# 24/24 - 1s - loss: 4.2422e-05 - 586ms/epoch - 24ms/step
# Epoch 84/200
# 24/24 - 1s - loss: 3.9532e-05 - 601ms/epoch - 25ms/step
# Epoch 85/200
# 24/24 - 1s - loss: 4.3708e-05 - 579ms/epoch - 24ms/step
# Epoch 86/200
# 24/24 - 1s - loss: 4.6637e-05 - 586ms/epoch - 24ms/step
# Epoch 87/200
# 24/24 - 1s - loss: 4.3141e-05 - 586ms/epoch - 24ms/step
# Epoch 88/200
# 24/24 - 1s - loss: 4.0841e-05 - 601ms/epoch - 25ms/step
# Epoch 89/200
# 24/24 - 1s - loss: 4.3079e-05 - 589ms/epoch - 25ms/step
# Epoch 90/200
# 24/24 - 1s - loss: 3.9543e-05 - 598ms/epoch - 25ms/step
# Epoch 91/200
# 24/24 - 1s - loss: 4.6601e-05 - 638ms/epoch - 27ms/step
# Epoch 92/200
# 24/24 - 1s - loss: 4.3514e-05 - 630ms/epoch - 26ms/step
# Epoch 93/200
# 24/24 - 1s - loss: 3.5104e-05 - 616ms/epoch - 26ms/step
# Epoch 94/200
# 24/24 - 1s - loss: 3.6732e-05 - 642ms/epoch - 27ms/step
# Epoch 95/200
# 24/24 - 1s - loss: 3.9872e-05 - 625ms/epoch - 26ms/step
# Epoch 96/200
# 24/24 - 1s - loss: 3.4340e-05 - 618ms/epoch - 26ms/step
# Epoch 97/200
# 24/24 - 1s - loss: 3.5944e-05 - 619ms/epoch - 26ms/step
# Epoch 98/200
# 24/24 - 1s - loss: 4.1432e-05 - 598ms/epoch - 25ms/step
# Epoch 99/200
# 24/24 - 1s - loss: 3.9614e-05 - 616ms/epoch - 26ms/step
# Epoch 100/200
# 24/24 - 1s - loss: 3.5597e-05 - 622ms/epoch - 26ms/step
# Epoch 101/200
# 24/24 - 1s - loss: 3.2551e-05 - 614ms/epoch - 26ms/step
# Epoch 102/200
# 24/24 - 1s - loss: 3.6539e-05 - 630ms/epoch - 26ms/step
# Epoch 103/200
# 24/24 - 1s - loss: 3.4087e-05 - 581ms/epoch - 24ms/step
# Epoch 104/200
# 24/24 - 1s - loss: 4.0606e-05 - 586ms/epoch - 24ms/step
# Epoch 105/200
# 24/24 - 1s - loss: 4.2237e-05 - 608ms/epoch - 25ms/step
# Epoch 106/200
# 24/24 - 1s - loss: 3.2654e-05 - 571ms/epoch - 24ms/step
# Epoch 107/200
# 24/24 - 1s - loss: 3.3595e-05 - 592ms/epoch - 25ms/step
# Epoch 108/200
# 24/24 - 1s - loss: 3.2331e-05 - 586ms/epoch - 24ms/step
# Epoch 109/200
# 24/24 - 1s - loss: 3.3885e-05 - 601ms/epoch - 25ms/step
# Epoch 110/200
# 24/24 - 1s - loss: 3.6200e-05 - 586ms/epoch - 24ms/step
# Epoch 111/200
# 24/24 - 1s - loss: 3.3694e-05 - 586ms/epoch - 24ms/step
# Epoch 112/200
# 24/24 - 1s - loss: 3.4475e-05 - 595ms/epoch - 25ms/step
# Epoch 113/200
# 24/24 - 1s - loss: 3.1956e-05 - 635ms/epoch - 26ms/step
# Epoch 114/200
# 24/24 - 1s - loss: 3.3722e-05 - 589ms/epoch - 25ms/step
# Epoch 115/200
# 24/24 - 1s - loss: 3.0409e-05 - 617ms/epoch - 26ms/step
# Epoch 116/200
# 24/24 - 1s - loss: 3.5036e-05 - 601ms/epoch - 25ms/step
# Epoch 117/200
# 24/24 - 1s - loss: 3.0511e-05 - 601ms/epoch - 25ms/step
# Epoch 118/200
# 24/24 - 1s - loss: 3.2752e-05 - 617ms/epoch - 26ms/step
# Epoch 119/200
# 24/24 - 1s - loss: 2.9718e-05 - 600ms/epoch - 25ms/step
# Epoch 120/200
# 24/24 - 1s - loss: 3.2573e-05 - 601ms/epoch - 25ms/step
# Epoch 121/200
# 24/24 - 1s - loss: 3.0686e-05 - 586ms/epoch - 24ms/step
# Epoch 122/200
# 24/24 - 1s - loss: 2.8697e-05 - 594ms/epoch - 25ms/step
# Epoch 123/200
# 24/24 - 1s - loss: 2.9602e-05 - 585ms/epoch - 24ms/step
# Epoch 124/200
# 24/24 - 1s - loss: 3.1121e-05 - 601ms/epoch - 25ms/step
# Epoch 125/200
# 24/24 - 1s - loss: 2.9727e-05 - 601ms/epoch - 25ms/step
# Epoch 126/200
# 24/24 - 1s - loss: 3.2575e-05 - 601ms/epoch - 25ms/step
# Epoch 127/200
# 24/24 - 1s - loss: 3.9509e-05 - 602ms/epoch - 25ms/step
# Epoch 128/200
# 24/24 - 1s - loss: 4.0646e-05 - 623ms/epoch - 26ms/step
# Epoch 129/200
# 24/24 - 1s - loss: 3.7011e-05 - 618ms/epoch - 26ms/step
# Epoch 130/200
# 24/24 - 1s - loss: 2.9991e-05 - 601ms/epoch - 25ms/step
# Epoch 131/200
# 24/24 - 1s - loss: 3.3547e-05 - 594ms/epoch - 25ms/step
# Epoch 132/200
# 24/24 - 1s - loss: 3.3203e-05 - 595ms/epoch - 25ms/step
# Epoch 133/200
# 24/24 - 1s - loss: 2.8779e-05 - 586ms/epoch - 24ms/step
# Epoch 134/200
# 24/24 - 1s - loss: 2.9400e-05 - 602ms/epoch - 25ms/step
# Epoch 135/200
# 24/24 - 1s - loss: 3.0291e-05 - 596ms/epoch - 25ms/step
# Epoch 136/200
# 24/24 - 1s - loss: 2.9027e-05 - 572ms/epoch - 24ms/step
# Epoch 137/200
# 24/24 - 1s - loss: 3.2516e-05 - 589ms/epoch - 25ms/step
# Epoch 138/200
# 24/24 - 1s - loss: 3.4025e-05 - 601ms/epoch - 25ms/step
# Epoch 139/200
# 24/24 - 1s - loss: 2.8606e-05 - 586ms/epoch - 24ms/step
# Epoch 140/200
# 24/24 - 1s - loss: 3.2316e-05 - 586ms/epoch - 24ms/step
# Epoch 141/200
# 24/24 - 1s - loss: 2.8818e-05 - 595ms/epoch - 25ms/step
# Epoch 142/200
# 24/24 - 1s - loss: 2.8720e-05 - 585ms/epoch - 24ms/step
# Epoch 143/200
# 24/24 - 1s - loss: 3.1900e-05 - 601ms/epoch - 25ms/step
# Epoch 144/200
# 24/24 - 1s - loss: 2.8848e-05 - 608ms/epoch - 25ms/step
# Epoch 145/200
# 24/24 - 1s - loss: 3.3903e-05 - 593ms/epoch - 25ms/step
# Epoch 146/200
# 24/24 - 1s - loss: 2.8448e-05 - 585ms/epoch - 24ms/step
# Epoch 147/200
# 24/24 - 1s - loss: 3.6734e-05 - 595ms/epoch - 25ms/step
# Epoch 148/200
# 24/24 - 1s - loss: 3.3890e-05 - 595ms/epoch - 25ms/step
# Epoch 149/200
# 24/24 - 1s - loss: 3.3116e-05 - 585ms/epoch - 24ms/step
# Epoch 150/200
# 24/24 - 1s - loss: 3.0681e-05 - 585ms/epoch - 24ms/step
# Epoch 151/200
# 24/24 - 1s - loss: 3.6570e-05 - 586ms/epoch - 24ms/step
# Epoch 152/200
# 24/24 - 1s - loss: 3.0979e-05 - 603ms/epoch - 25ms/step
# Epoch 153/200
# 24/24 - 1s - loss: 3.2275e-05 - 587ms/epoch - 24ms/step
# Epoch 154/200
# 24/24 - 1s - loss: 3.4408e-05 - 582ms/epoch - 24ms/step
# Epoch 155/200
# 24/24 - 1s - loss: 3.9093e-05 - 602ms/epoch - 25ms/step
# Epoch 156/200
# 24/24 - 1s - loss: 3.2225e-05 - 601ms/epoch - 25ms/step
# Epoch 157/200
# 24/24 - 1s - loss: 2.8560e-05 - 601ms/epoch - 25ms/step
# Epoch 158/200
# 24/24 - 1s - loss: 2.9246e-05 - 601ms/epoch - 25ms/step
# Epoch 159/200
# 24/24 - 1s - loss: 3.4532e-05 - 617ms/epoch - 26ms/step
# Epoch 160/200
# 24/24 - 1s - loss: 3.4561e-05 - 602ms/epoch - 25ms/step
# Epoch 161/200
# 24/24 - 1s - loss: 3.3093e-05 - 602ms/epoch - 25ms/step
# Epoch 162/200
# 24/24 - 1s - loss: 3.1317e-05 - 583ms/epoch - 24ms/step
# Epoch 163/200
# 24/24 - 1s - loss: 3.3523e-05 - 601ms/epoch - 25ms/step
# Epoch 164/200
# 24/24 - 1s - loss: 3.4055e-05 - 601ms/epoch - 25ms/step
# Epoch 165/200
# 24/24 - 1s - loss: 3.4960e-05 - 601ms/epoch - 25ms/step
# Epoch 166/200
# 24/24 - 1s - loss: 2.7759e-05 - 586ms/epoch - 24ms/step
# Epoch 167/200
# 24/24 - 1s - loss: 3.3500e-05 - 613ms/epoch - 26ms/step
# Epoch 168/200
# 24/24 - 1s - loss: 3.3504e-05 - 601ms/epoch - 25ms/step
# Epoch 169/200
# 24/24 - 1s - loss: 3.0128e-05 - 606ms/epoch - 25ms/step
# Epoch 170/200
# 24/24 - 1s - loss: 3.6883e-05 - 617ms/epoch - 26ms/step
# Epoch 171/200
# 24/24 - 1s - loss: 3.1730e-05 - 586ms/epoch - 24ms/step
# Epoch 172/200
# 24/24 - 1s - loss: 3.2257e-05 - 602ms/epoch - 25ms/step
# Epoch 173/200
# 24/24 - 1s - loss: 2.8409e-05 - 585ms/epoch - 24ms/step
# Epoch 174/200
# 24/24 - 1s - loss: 2.9210e-05 - 595ms/epoch - 25ms/step
# Epoch 175/200
# 24/24 - 1s - loss: 2.8796e-05 - 587ms/epoch - 24ms/step
# Epoch 176/200
# 24/24 - 1s - loss: 2.9186e-05 - 639ms/epoch - 27ms/step
# Epoch 177/200
# 24/24 - 1s - loss: 2.9928e-05 - 585ms/epoch - 24ms/step
# Epoch 178/200
# 24/24 - 1s - loss: 2.8752e-05 - 602ms/epoch - 25ms/step
# Epoch 179/200
# 24/24 - 1s - loss: 3.0656e-05 - 631ms/epoch - 26ms/step
# Epoch 180/200
# 24/24 - 1s - loss: 2.8624e-05 - 601ms/epoch - 25ms/step
# Epoch 181/200
# 24/24 - 1s - loss: 2.9845e-05 - 585ms/epoch - 24ms/step
# Epoch 182/200
# 24/24 - 1s - loss: 2.9806e-05 - 639ms/epoch - 27ms/step
# Epoch 183/200
# 24/24 - 1s - loss: 3.8288e-05 - 634ms/epoch - 26ms/step
# Epoch 184/200
# 24/24 - 1s - loss: 2.8669e-05 - 623ms/epoch - 26ms/step
# Epoch 185/200
# 24/24 - 1s - loss: 3.4510e-05 - 624ms/epoch - 26ms/step
# Epoch 186/200
# 24/24 - 1s - loss: 3.2921e-05 - 617ms/epoch - 26ms/step
# Epoch 187/200
# 24/24 - 1s - loss: 3.4538e-05 - 627ms/epoch - 26ms/step
# Epoch 188/200
# 24/24 - 1s - loss: 3.1991e-05 - 614ms/epoch - 26ms/step
# Epoch 189/200
# 24/24 - 1s - loss: 3.3755e-05 - 617ms/epoch - 26ms/step
# Epoch 190/200
# 24/24 - 1s - loss: 2.9116e-05 - 601ms/epoch - 25ms/step
# Epoch 191/200
# 24/24 - 1s - loss: 2.9124e-05 - 586ms/epoch - 24ms/step
# Epoch 192/200
# 24/24 - 1s - loss: 2.8904e-05 - 586ms/epoch - 24ms/step
# Epoch 193/200
# 24/24 - 1s - loss: 3.2326e-05 - 601ms/epoch - 25ms/step
# Epoch 194/200
# 24/24 - 1s - loss: 3.1382e-05 - 601ms/epoch - 25ms/step
# Epoch 195/200
# 24/24 - 1s - loss: 2.8900e-05 - 591ms/epoch - 25ms/step
# Epoch 196/200
# 24/24 - 1s - loss: 3.0988e-05 - 581ms/epoch - 24ms/step
# Epoch 197/200
# 24/24 - 1s - loss: 2.7640e-05 - 615ms/epoch - 26ms/step
# Epoch 198/200
# 24/24 - 1s - loss: 2.7978e-05 - 613ms/epoch - 26ms/step
# Epoch 199/200
# 24/24 - 1s - loss: 3.1244e-05 - 629ms/epoch - 26ms/step
# Epoch 200/200
# 24/24 - 1s - loss: 2.9815e-05 - 615ms/epoch - 26ms/step

# %% [markdown]
# # Xây dựng tập thử nghiệm test

# %%
#tạo tập dữ liệu test với timestep=60 ngày tương tự như tập train
testingData = scaledData[trainingDataLength - 60: , :]

#tạo tập Xtest và Ytest
Xtest = []
Ytest = stock_close_dataset[trainingDataLength:, :]
for i in range(60, len(testingData)):
  Xtest.append(testingData[i-60:i, 0])

# %%
#chuyển dữ liệu Xtest thành mảng numpy
Xtest = np.array(Xtest)
Xtest
# Out:
# array([[0.27633107, 0.27525294, 0.26629623, ..., 0.36042461, 0.35063858,
#         0.35536573],
#        [0.27525294, 0.26629623, 0.26861834, ..., 0.35063858, 0.35536573,
#         0.36332725],
#        [0.26629623, 0.26861834, 0.27027699, ..., 0.35536573, 0.36332725,
#         0.37402554],
#        ...,
#        [0.77500415, 0.77964837, 0.80004976, ..., 0.88978272, 0.85768784,
#         0.85652679],
#        [0.77964837, 0.80004976, 0.83048598, ..., 0.85768784, 0.85652679,
#         0.85229723],
#        [0.80004976, 0.83048598, 0.83347155, ..., 0.85652679, 0.85229723,
#         0.81613866]])

# %%
#Reshape dữ liệu 
Xtest = np.reshape(Xtest, (Xtest.shape[0], Xtest.shape[1], 1 ))

# %%
#Chuyển đổi về dạng giá thông thường mà ta đọc được 
predictions = model.predict(Xtest)
predictions = scaler.inverse_transform(predictions)
predictions
# Out:
# 10/10 [==============================] - 1s 10ms/step
# array([[ 65.62217 ],
#        [ 66.42355 ],
#        [ 67.66189 ],
#        [ 66.39526 ],
#        [ 67.20185 ],
#        [ 67.68925 ],
#        [ 67.80316 ],
#        [ 68.86563 ],
#        [ 69.98685 ],
#        [ 69.97644 ],
#        [ 69.9038  ],
#        [ 70.073586],
#        [ 69.89961 ],
#        [ 71.223946],
#        [ 70.98464 ],
#        [ 72.679955],
#        [ 72.28795 ],
#        [ 72.96784 ],
#        [ 73.46797 ],
#        [ 75.30953 ],
#        [ 74.0834  ],
#        [ 75.19236 ],
#        [ 74.543495],
#        [ 76.10898 ],
#        [ 77.54701 ],
#        [ 77.425415],
#        [ 79.51095 ],
#        [ 77.81307 ],
#        [ 78.026344],
#        [ 79.11138 ],
#        [ 79.77156 ],
#        [ 78.97847 ],
#        [ 79.59623 ],
#        [ 79.857124],
#        [ 79.50971 ],
#        [ 76.89261 ],
#        [ 80.132   ],
#        [ 80.98872 ],
#        [ 80.63612 ],
#        [ 76.6977  ],
#        [ 77.64007 ],
#        [ 80.121574],
#        [ 80.01473 ],
#        [ 81.222404],
#        [ 79.49895 ],
#        [ 80.57412 ],
#        [ 79.69546 ],
#        [ 82.16593 ],
#        [ 80.75187 ],
#        [ 81.284386],
#        [ 79.41794 ],
#        [ 81.29734 ],
#        [ 79.677124],
#        [ 78.01599 ],
#        [ 74.09075 ],
#        [ 72.0673  ],
#        [ 73.5425  ],
#        [ 67.27634 ],
#        [ 68.63458 ],
#        [ 75.199745],
#        [ 70.72988 ],
#        [ 75.98364 ],
#        [ 72.05427 ],
#        [ 72.22957 ],
#        [ 65.74759 ],
#        [ 72.61822 ],
#        [ 67.8594  ],
#        [ 61.34477 ],
#        [ 70.93935 ],
#        [ 58.49151 ],
#        [ 64.16409 ],
#        [ 60.99581 ],
#        [ 60.9906  ],
#        [ 56.668415],
#        [ 56.043976],
#        [ 62.024376],
#        [ 60.499268],
#        [ 64.49448 ],
#        [ 61.062614],
#        [ 63.90401 ],
#        [ 63.321472],
#        [ 59.899265],
#        [ 61.65845 ],
#        [ 60.235233],
#        [ 66.16485 ],
#        [ 64.1899  ],
#        [ 66.627045],
#        [ 66.832596],
#        [ 68.415794],
#        [ 72.07015 ],
#        [ 70.721306],
#        [ 71.93584 ],
#        [ 70.70324 ],
#        [ 69.39753 ],
#        [ 67.23265 ],
#        [ 69.72333 ],
#        [ 68.615746],
#        [ 71.02438 ],
#        [ 70.50752 ],
#        [ 69.429054],
#        [ 72.33424 ],
#        [ 73.36828 ],
#        [ 71.90664 ],
#        [ 73.58824 ],
#        [ 74.468735],
#        [ 75.19265 ],
#        [ 75.99647 ],
#        [ 77.731415],
#        [ 78.793655],
#        [ 77.63349 ],
#        [ 77.01992 ],
#        [ 77.75061 ],
#        [ 76.92846 ],
#        [ 79.18609 ],
#        [ 77.98318 ],
#        [ 80.13482 ],
#        [ 78.867424],
#        [ 79.90853 ],
#        [ 79.01412 ],
#        [ 79.6953  ],
#        [ 79.51222 ],
#        [ 79.469444],
#        [ 80.60327 ],
#        [ 80.69861 ],
#        [ 81.25006 ],
#        [ 80.33601 ],
#        [ 83.35028 ],
#        [ 83.03236 ],
#        [ 86.36734 ],
#        [ 88.12578 ],
#        [ 82.82895 ],
#        [ 85.656105],
#        [ 85.89103 ],
#        [ 88.38991 ],
#        [ 87.4806  ],
#        [ 87.97033 ],
#        [ 87.313774],
#        [ 90.28359 ],
#        [ 91.575935],
#        [ 89.33754 ],
#        [ 91.76428 ],
#        [ 87.581375],
#        [ 91.45597 ],
#        [ 90.88697 ],
#        [ 90.846405],
#        [ 90.940926],
#        [ 93.85313 ],
#        [ 92.51361 ],
#        [ 95.78959 ],
#        [ 95.26445 ],
#        [ 95.865875],
#        [ 95.289276],
#        [ 97.4922  ],
#        [ 97.48705 ],
#        [ 96.10224 ],
#        [ 96.47846 ],
#        [ 98.7487  ],
#        [ 96.14168 ],
#        [ 97.53817 ],
#        [ 91.53428 ],
#        [ 93.380875],
#        [ 95.001526],
#        [ 92.17525 ],
#        [ 95.40923 ],
#        [ 95.59948 ],
#        [107.823746],
#        [106.94596 ],
#        [109.253296],
#        [109.87087 ],
#        [114.94961 ],
#        [109.683075],
#        [114.35709 ],
#        [108.069725],
#        [115.20781 ],
#        [114.32813 ],
#        [114.52194 ],
#        [114.32987 ],
#        [115.67666 ],
#        [115.23653 ],
#        [118.71548 ],
#        [124.89004 ],
#        [124.27549 ],
#        [124.07474 ],
#        [127.01725 ],
#        [123.820145],
#        [125.23843 ],
#        [129.858   ],
#        [133.98045 ],
#        [128.72578 ],
#        [118.35895 ],
#        [123.69373 ],
#        [108.97115 ],
#        [120.88653 ],
#        [109.110245],
#        [112.2183  ],
#        [114.84236 ],
#        [113.40001 ],
#        [109.98766 ],
#        [109.5531  ],
#        [105.12967 ],
#        [110.89774 ],
#        [110.1942  ],
#        [104.59421 ],
#        [108.77192 ],
#        [111.91128 ],
#        [113.88943 ],
#        [112.45491 ],
#        [115.87675 ],
#        [115.94174 ],
#        [111.40718 ],
#        [118.100235],
#        [110.62123 ],
#        [116.462425],
#        [113.56561 ],
#        [117.289604],
#        [125.08732 ],
#        [117.58587 ],
#        [122.14205 ],
#        [119.71933 ],
#        [118.583275],
#        [115.136284],
#        [118.346954],
#        [115.488075],
#        [115.1299  ],
#        [114.27162 ],
#        [114.44372 ],
#        [116.17459 ],
#        [108.37112 ],
#        [117.26697 ],
#        [104.62905 ],
#        [110.22846 ],
#        [109.5261  ],
#        [115.04389 ],
#        [117.93039 ],
#        [116.79837 ],
#        [115.180336],
#        [115.9476  ],
#        [120.02867 ],
#        [117.7121  ],
#        [119.10322 ],
#        [119.96436 ],
#        [118.4037  ],
#        [117.48648 ],
#        [118.62326 ],
#        [116.17959 ],
#        [112.700676],
#        [115.79336 ],
#        [114.97973 ],
#        [115.86404 ],
#        [118.68877 ],
#        [122.20462 ],
#        [121.46001 ],
#        [122.304855],
#        [121.484085],
#        [123.9476  ],
#        [123.58136 ],
#        [120.46784 ],
#        [123.9305  ],
#        [120.93259 ],
#        [121.441246],
#        [128.91902 ],
#        [125.124855],
#        [128.69763 ],
#        [124.80596 ],
#        [128.92422 ],
#        [131.56842 ],
#        [129.07143 ],
#        [132.0985  ],
#        [136.83762 ],
#        [132.21066 ],
#        [133.70554 ],
#        [131.73532 ],
#        [128.14157 ],
#        [131.7674  ],
#        [123.46047 ],
#        [133.00772 ],
#        [129.23657 ],
#        [127.136024],
#        [128.40086 ],
#        [130.24307 ],
#        [126.57363 ],
#        [126.31265 ],
#        [127.26369 ],
#        [131.89449 ],
#        [135.80304 ],
#        [137.24321 ],
#        [142.47444 ],
#        [141.04402 ],
#        [141.27005 ],
#        [135.11923 ],
#        [131.50981 ],
#        [135.48091 ],
#        [133.23683 ],
#        [132.5012  ],
#        [137.34941 ],
#        [133.86166 ],
#        [136.23952 ],
#        [134.10466 ],
#        [134.45041 ],
#        [133.92256 ],
#        [134.34566 ],
#        [131.15799 ],
#        [129.67548 ],
#        [128.67995 ],
#        [128.89915 ],
#        [123.29988 ],
#        [125.79063 ],
#        [123.41711 ],
#        [118.539894]], dtype=float32)

# %%
#vẽ biểu đồ để biễu diễn dự đoán 
#chia tệp data thành tập train và reality sau đó xây dựng tệp predictions để so sánh 
training = stock_close_data[:trainingDataLength]
reality= stock_close_data[trainingDataLength:]
reality['Predictions'] = predictions

root = tkinter.Tk()
fig = mtlplt.figure(figsize=(20,10))
mtlplt.title('VNINDEX')
mtlplt.xlabel('Date', fontsize=20)
mtlplt.ylabel('Close Stock Price $ (VND)', fontsize=20)
mtlplt.plot(training['Close'])
mtlplt.plot(reality[['Close', 'Predictions']])
mtlplt.legend(['Training', 'Reality', 'Predictions'], loc='lower right')
canvas = FigureCanvasTkAgg(fig, master=root) 
canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

toolbar = NavigationToolbar2Tk(canvas, root)
toolbar.update()
canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

root.geometry('1400x900')
root.mainloop()

# %%
#Show dữ liệu Close và Predictions
reality
# Out:
#              Close  Predictions
# Date
# 2019-12-05   66.39    65.622169
# 2019-12-06   67.68    66.423553
# 2019-12-09   66.73    67.661888
# 2019-12-10   67.12    66.395264
# 2019-12-11   67.69    67.201851
# ...            ...          ...
# 2021-02-22  126.00   128.899155
# 2021-02-23  125.86   123.299881
# 2021-02-24  125.35   125.790627
# 2021-02-25  120.99   123.417107
# 2021-02-26  121.26   118.539894
#
# [309 rows x 2 columns]

# %%
#In kết quả của giá đóng và giá dự đoán ra file csv
reality.to_csv('APPL_Ketquadubao.csv')

# %%
mae = np.mean(np.abs(Ytest - predictions ))
print(mae)
rmse = np.sqrt(np.mean((Ytest - predictions) ** 2))
print(rmse)
#tính độ chính xác của dự báo
mape = np.mean(np.abs((Ytest - predictions )/ Ytest)) *100
print(mape)
# Out:
# 2.0545705347153747
# 2.8306637674349036
# 2.150992686286229
