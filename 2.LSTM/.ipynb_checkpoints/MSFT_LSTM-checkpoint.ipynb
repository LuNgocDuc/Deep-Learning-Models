# %% [markdown]
# # Import thư viện cần thiết

# %%
#bỏ qua các cảnh báo
import warnings
warnings.filterwarnings('ignore')
#thư viện toán học cho hàm toán học
import math
#dùng để đọc dữ liệu
import pandas as pd
#giúp xử lý số liệu
import numpy as np
#dùng để chuẩn hóa dữ liệu
from sklearn.preprocessing import MinMaxScaler
#cài keras - thư viện mạng thần kinh for LSTM
from keras.layers import LSTM
from keras.layers import Dense
from keras.models import Sequential
#dùng để vẽ biểu đồ 
import matplotlib.pyplot as mtlplt
mtlplt.style.use("fivethirtyeight")
# %matplotlib inline
from matplotlib import rcParams 
import tkinter
from matplotlib.backends.backend_tkagg import (
    FigureCanvasTkAgg, NavigationToolbar2Tk)
# Out:
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
AAPL = pd.read_csv("./Database/Pre_Processed_AMZN.csv")

# %% [markdown]
# # Lấy data từ file

# %%
file = './Database/Pre_Processed_AMZN.csv' #dữ liệu được tải về từ trang tradingview.com được niêm yết trên thị trường chứng khoán VN
df = pd.read_csv(file,parse_dates=True,index_col=0)
data = df.reset_index('Date') #đặt cột Date làm chỉ mục
data
# Out:
#            Date     Open     High      Low    Close  Adj. Close     Volume
# 0    2015-01-02   312.58   314.75   306.96   308.52      308.52  2783200.0
# 1    2015-01-05   307.01   308.38   300.85   302.19      302.19  2774200.0
# 2    2015-01-06   302.24   303.00   292.38   295.29      295.29  3519000.0
# 3    2015-01-07   297.50   301.28   295.33   298.42      298.42  2640300.0
# 4    2015-01-08   300.32   303.14   296.11   300.46      300.46  3088400.0
# ...         ...      ...      ...      ...      ...         ...        ...
# 1544 2021-02-22  3208.13  3232.32  3172.26  3180.74     3180.74  3504600.0
# 1545 2021-02-23  3127.03  3204.73  3093.60  3194.50     3194.50  4669500.0
# 1546 2021-02-24  3166.75  3171.23  3125.38  3159.53     3159.53  3003000.0
# 1547 2021-02-25  3136.74  3178.26  3047.76  3057.16     3057.16  4507100.0
# 1548 2021-02-26  3095.20  3122.44  3036.70  3092.93     3092.93  4273500.0
#
# [1549 rows x 7 columns]

# %% [markdown]
# # Lấy số lượng cột và hàng

# %%
df.shape
# Out:
# (1549, 6)

# %% [markdown]
# # Vẽ biểu đồ từ dữ liệu

# %%
#Đây là biểu đồ giá đóng cửa của data từ khoảng thời gian 1/4/2016 đến 10/1/2022
mtlplt.figure(figsize=(18,9))
mtlplt.title('Close price history data')
mtlplt.plot(df['Close']) 
mtlplt.xlabel('Date', fontsize=20) #trục x biễu diễn cột Date
mtlplt.ylabel('Close price in $(VND)',fontsize=20) #trục y biểu diễn giá đóng trong ngày
mtlplt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Tiền xử lý tập dữ liệu

# %%
#Tạo dataframe chỉ có cột giá đóng
stock_close_data = df.filter(['Close'])

#chuyển đổi dataframe đã tạo thành mảng numpy bằng hàm values
stock_close_dataset = stock_close_data.values

#chia dữ liệu thành tập train and test(train chiếm 80% data và test 20% còn lại của data)
trainingDataLength = math.ceil( len(stock_close_dataset) * 0.8 )

#hiển thị độ dài tập trai
trainingDataLength
# Out:
# 1240

# %%
#Scale dữ liệu về dạng 0,1 giúp model train nhanh hơn. 
#Lstm hoạt động tốt hơn khi các giá trị đầu vào được chia tỷ lệ thành phạm vi tiêu chuẩn
scaler = MinMaxScaler(feature_range=(0,1))

#tiến hành scale dữ liệu bằng fit.trainsform
scaledData = scaler.fit_transform(stock_close_dataset)

#hiển thị giá trị dữ liệu được chia
scaledData.shape
# Out:
# (1549, 1)

# %%
#tạo tập dữ liệu mới chứa giá trị giá trị scale có kích thước từ 0 đến kích thươc dữ liệu 80% ở trên
StockTrainData = scaledData[0:trainingDataLength , :]

#tách dữ liệu thành 2 phần Xtrain và Ytrain
Xtrain = []
Ytrain = []
#tiến hành tạo dữ lieu cho xtrain và ytrain bằng vòng lặp trong phạm vi từ 60 đến tổng kích thước dữ liệu huấn luyện
#tạo dữ liệu với timestep=60 ngày, xem xét dữ liệu quá khứ để đoán ra ngày 61 
for i in range(60, len(StockTrainData)):
  Xtrain.append(StockTrainData[i-60:i, 0])
  Ytrain.append(StockTrainData[i, 0])
  if i<= 61:
    print(Xtrain)
    print(Ytrain)
    print()
# Out:
# [array([0.00664817, 0.00469718, 0.0025705 , 0.00353521, 0.00416397,
#        0.00307597, 0.00137463, 0.00240099, 0.00194791, 0.        ,
#        0.00116813, 0.00076745, 0.0031746 , 0.00720296, 0.00784096,
#        0.00699954, 0.00610264, 0.00522731, 0.00765295, 0.0208291 ,
#        0.02389274, 0.02360918, 0.02397904, 0.02679612, 0.02691632,
#        0.02576976, 0.02652181, 0.02718138, 0.02780706, 0.02924333,
#        0.02727077, 0.02663585, 0.02837109, 0.02980737, 0.02872245,
#        0.02824472, 0.03033441, 0.03015873, 0.02872862, 0.03042379,
#        0.03010017, 0.02951765, 0.03109262, 0.02870704, 0.02823548,
#        0.02544614, 0.02447835, 0.02690399, 0.02577593, 0.02662968,
#        0.02618894, 0.02718138, 0.02659578, 0.0282139 , 0.02717214,
#        0.02685776, 0.02589305, 0.0247804 , 0.02576976, 0.02701187])]
# [0.026244413623054408]
#
# [array([0.00664817, 0.00469718, 0.0025705 , 0.00353521, 0.00416397,
#        0.00307597, 0.00137463, 0.00240099, 0.00194791, 0.        ,
#        0.00116813, 0.00076745, 0.0031746 , 0.00720296, 0.00784096,
#        0.00699954, 0.00610264, 0.00522731, 0.00765295, 0.0208291 ,
#        0.02389274, 0.02360918, 0.02397904, 0.02679612, 0.02691632,
#        0.02576976, 0.02652181, 0.02718138, 0.02780706, 0.02924333,
#        0.02727077, 0.02663585, 0.02837109, 0.02980737, 0.02872245,
#        0.02824472, 0.03033441, 0.03015873, 0.02872862, 0.03042379,
#        0.03010017, 0.02951765, 0.03109262, 0.02870704, 0.02823548,
#        0.02544614, 0.02447835, 0.02690399, 0.02577593, 0.02662968,
#        0.02618894, 0.02718138, 0.02659578, 0.0282139 , 0.02717214,
#        0.02685776, 0.02589305, 0.0247804 , 0.02576976, 0.02701187]), array([0.00469718, 0.0025705 , 0.00353521, 0.00416397, 0.00307597,
#        0.00137463, 0.00240099, 0.00194791, 0.        , 0.00116813,
#        0.00076745, 0.0031746 , 0.00720296, 0.00784096, 0.00699954,
#        0.00610264, 0.00522731, 0.00765295, 0.0208291 , 0.02389274,
#        0.02360918, 0.02397904, 0.02679612, 0.02691632, 0.02576976,
#        0.02652181, 0.02718138, 0.02780706, 0.02924333, 0.02727077,
#        0.02663585, 0.02837109, 0.02980737, 0.02872245, 0.02824472,
#        0.03033441, 0.03015873, 0.02872862, 0.03042379, 0.03010017,
#        0.02951765, 0.03109262, 0.02870704, 0.02823548, 0.02544614,
#        0.02447835, 0.02690399, 0.02577593, 0.02662968, 0.02618894,
#        0.02718138, 0.02659578, 0.0282139 , 0.02717214, 0.02685776,
#        0.02589305, 0.0247804 , 0.02576976, 0.02701187, 0.02624441])]
# [0.026244413623054408, 0.025677300046232088]

# %%
#chuyển đổi dữ liệu Xtrain, dữ liệu Ytrain thành mảng numpy 
Xtrain = np.array(Xtrain)
Ytrain = np.array(Ytrain)

# %%
#định hình lại dữ liệu Xtrain cho phù hợp với dữ liệu đầu vào thành dạng 3D và 1 đối tượng đại diện giá đóng cửa
Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], Xtrain.shape[1], 1))
Xtrain.shape
# Out:
# (1180, 60, 1)

# %% [markdown]
# # Tạo model và xây dựng mô hình LSTM

# %%
#khởi tạo model
model = Sequential()

neurons = 50

#lớp LSTM đầu
model.add(LSTM(neurons, return_sequences=True, input_shape= (Xtrain.shape[1], 1))) 

#lớp LSTM thứ 2, không còn lớp nào cho lstm nên return_sequences= False
model.add(LSTM(neurons, return_sequences= False)) 

#thêm lớp nơron dày đặc
model.add(Dense(25)) 
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#biên dịch model
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#đào tạo với tập Xtrain, Ytrain đã cho
history_data = model.fit(Xtrain, Ytrain, batch_size=50, epochs=200, verbose=2)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 24/24 - 5s - loss: 0.0148 - 5s/epoch - 190ms/step
# Epoch 2/200
# 24/24 - 1s - loss: 9.6422e-04 - 595ms/epoch - 25ms/step
# Epoch 3/200
# 24/24 - 1s - loss: 3.3520e-04 - 602ms/epoch - 25ms/step
# Epoch 4/200
# 24/24 - 1s - loss: 2.5131e-04 - 601ms/epoch - 25ms/step
# Epoch 5/200
# 24/24 - 1s - loss: 2.3918e-04 - 602ms/epoch - 25ms/step
# Epoch 6/200
# 24/24 - 1s - loss: 2.3355e-04 - 595ms/epoch - 25ms/step
# Epoch 7/200
# 24/24 - 1s - loss: 2.4928e-04 - 595ms/epoch - 25ms/step
# Epoch 8/200
# 24/24 - 1s - loss: 2.1906e-04 - 586ms/epoch - 24ms/step
# Epoch 9/200
# 24/24 - 1s - loss: 2.1652e-04 - 590ms/epoch - 25ms/step
# Epoch 10/200
# 24/24 - 1s - loss: 2.1778e-04 - 586ms/epoch - 24ms/step
# Epoch 11/200
# 24/24 - 1s - loss: 2.1310e-04 - 586ms/epoch - 24ms/step
# Epoch 12/200
# 24/24 - 1s - loss: 2.0784e-04 - 586ms/epoch - 24ms/step
# Epoch 13/200
# 24/24 - 1s - loss: 2.1717e-04 - 601ms/epoch - 25ms/step
# Epoch 14/200
# 24/24 - 1s - loss: 2.2612e-04 - 586ms/epoch - 24ms/step
# Epoch 15/200
# 24/24 - 1s - loss: 2.1118e-04 - 586ms/epoch - 24ms/step
# Epoch 16/200
# 24/24 - 1s - loss: 2.0592e-04 - 601ms/epoch - 25ms/step
# Epoch 17/200
# 24/24 - 1s - loss: 2.0529e-04 - 586ms/epoch - 24ms/step
# Epoch 18/200
# 24/24 - 1s - loss: 2.0162e-04 - 618ms/epoch - 26ms/step
# Epoch 19/200
# 24/24 - 1s - loss: 2.0960e-04 - 601ms/epoch - 25ms/step
# Epoch 20/200
# 24/24 - 1s - loss: 1.8971e-04 - 601ms/epoch - 25ms/step
# Epoch 21/200
# 24/24 - 1s - loss: 1.8449e-04 - 617ms/epoch - 26ms/step
# Epoch 22/200
# 24/24 - 1s - loss: 1.8205e-04 - 601ms/epoch - 25ms/step
# Epoch 23/200
# 24/24 - 1s - loss: 1.9809e-04 - 601ms/epoch - 25ms/step
# Epoch 24/200
# 24/24 - 1s - loss: 1.8416e-04 - 601ms/epoch - 25ms/step
# Epoch 25/200
# 24/24 - 1s - loss: 1.9243e-04 - 602ms/epoch - 25ms/step
# Epoch 26/200
# 24/24 - 1s - loss: 2.0999e-04 - 586ms/epoch - 24ms/step
# Epoch 27/200
# 24/24 - 1s - loss: 1.8197e-04 - 648ms/epoch - 27ms/step
# Epoch 28/200
# 24/24 - 1s - loss: 1.6869e-04 - 648ms/epoch - 27ms/step
# Epoch 29/200
# 24/24 - 1s - loss: 1.6966e-04 - 630ms/epoch - 26ms/step
# Epoch 30/200
# 24/24 - 1s - loss: 1.8043e-04 - 600ms/epoch - 25ms/step
# Epoch 31/200
# 24/24 - 1s - loss: 1.7002e-04 - 602ms/epoch - 25ms/step
# Epoch 32/200
# 24/24 - 1s - loss: 1.6767e-04 - 586ms/epoch - 24ms/step
# Epoch 33/200
# 24/24 - 1s - loss: 1.6239e-04 - 601ms/epoch - 25ms/step
# Epoch 34/200
# 24/24 - 1s - loss: 1.8054e-04 - 585ms/epoch - 24ms/step
# Epoch 35/200
# 24/24 - 1s - loss: 1.5887e-04 - 601ms/epoch - 25ms/step
# Epoch 36/200
# 24/24 - 1s - loss: 1.6522e-04 - 585ms/epoch - 24ms/step
# Epoch 37/200
# 24/24 - 1s - loss: 1.5964e-04 - 594ms/epoch - 25ms/step
# Epoch 38/200
# 24/24 - 1s - loss: 1.7387e-04 - 580ms/epoch - 24ms/step
# Epoch 39/200
# 24/24 - 1s - loss: 1.5647e-04 - 592ms/epoch - 25ms/step
# Epoch 40/200
# 24/24 - 1s - loss: 1.5186e-04 - 586ms/epoch - 24ms/step
# Epoch 41/200
# 24/24 - 1s - loss: 1.8627e-04 - 601ms/epoch - 25ms/step
# Epoch 42/200
# 24/24 - 1s - loss: 1.6500e-04 - 592ms/epoch - 25ms/step
# Epoch 43/200
# 24/24 - 1s - loss: 1.5016e-04 - 654ms/epoch - 27ms/step
# Epoch 44/200
# 24/24 - 1s - loss: 1.5369e-04 - 625ms/epoch - 26ms/step
# Epoch 45/200
# 24/24 - 1s - loss: 1.9173e-04 - 655ms/epoch - 27ms/step
# Epoch 46/200
# 24/24 - 1s - loss: 1.6941e-04 - 670ms/epoch - 28ms/step
# Epoch 47/200
# 24/24 - 1s - loss: 1.9164e-04 - 626ms/epoch - 26ms/step
# Epoch 48/200
# 24/24 - 1s - loss: 1.8773e-04 - 617ms/epoch - 26ms/step
# Epoch 49/200
# 24/24 - 1s - loss: 1.7265e-04 - 614ms/epoch - 26ms/step
# Epoch 50/200
# 24/24 - 1s - loss: 1.3820e-04 - 589ms/epoch - 25ms/step
# Epoch 51/200
# 24/24 - 1s - loss: 1.3349e-04 - 601ms/epoch - 25ms/step
# Epoch 52/200
# 24/24 - 1s - loss: 1.3892e-04 - 617ms/epoch - 26ms/step
# Epoch 53/200
# 24/24 - 1s - loss: 1.5241e-04 - 586ms/epoch - 24ms/step
# Epoch 54/200
# 24/24 - 1s - loss: 1.3501e-04 - 586ms/epoch - 24ms/step
# Epoch 55/200
# 24/24 - 1s - loss: 1.4017e-04 - 601ms/epoch - 25ms/step
# Epoch 56/200
# 24/24 - 1s - loss: 1.3201e-04 - 595ms/epoch - 25ms/step
# Epoch 57/200
# 24/24 - 1s - loss: 1.2965e-04 - 579ms/epoch - 24ms/step
# Epoch 58/200
# 24/24 - 1s - loss: 1.2891e-04 - 591ms/epoch - 25ms/step
# Epoch 59/200
# 24/24 - 1s - loss: 1.3183e-04 - 585ms/epoch - 24ms/step
# Epoch 60/200
# 24/24 - 1s - loss: 1.3028e-04 - 601ms/epoch - 25ms/step
# Epoch 61/200
# 24/24 - 1s - loss: 1.3472e-04 - 586ms/epoch - 24ms/step
# Epoch 62/200
# 24/24 - 1s - loss: 1.2462e-04 - 602ms/epoch - 25ms/step
# Epoch 63/200
# 24/24 - 1s - loss: 1.1543e-04 - 586ms/epoch - 24ms/step
# Epoch 64/200
# 24/24 - 1s - loss: 1.3181e-04 - 601ms/epoch - 25ms/step
# Epoch 65/200
# 24/24 - 1s - loss: 1.1278e-04 - 589ms/epoch - 25ms/step
# Epoch 66/200
# 24/24 - 1s - loss: 1.3528e-04 - 598ms/epoch - 25ms/step
# Epoch 67/200
# 24/24 - 1s - loss: 1.2681e-04 - 595ms/epoch - 25ms/step
# Epoch 68/200
# 24/24 - 1s - loss: 1.1210e-04 - 607ms/epoch - 25ms/step
# Epoch 69/200
# 24/24 - 1s - loss: 1.0987e-04 - 601ms/epoch - 25ms/step
# Epoch 70/200
# 24/24 - 1s - loss: 1.3470e-04 - 601ms/epoch - 25ms/step
# Epoch 71/200
# 24/24 - 1s - loss: 1.2271e-04 - 595ms/epoch - 25ms/step
# Epoch 72/200
# 24/24 - 1s - loss: 1.1268e-04 - 602ms/epoch - 25ms/step
# Epoch 73/200
# 24/24 - 1s - loss: 1.2193e-04 - 606ms/epoch - 25ms/step
# Epoch 74/200
# 24/24 - 1s - loss: 1.5182e-04 - 581ms/epoch - 24ms/step
# Epoch 75/200
# 24/24 - 1s - loss: 1.1862e-04 - 585ms/epoch - 24ms/step
# Epoch 76/200
# 24/24 - 1s - loss: 1.2974e-04 - 601ms/epoch - 25ms/step
# Epoch 77/200
# 24/24 - 1s - loss: 1.0457e-04 - 601ms/epoch - 25ms/step
# Epoch 78/200
# 24/24 - 1s - loss: 1.1175e-04 - 586ms/epoch - 24ms/step
# Epoch 79/200
# 24/24 - 1s - loss: 9.9745e-05 - 601ms/epoch - 25ms/step
# Epoch 80/200
# 24/24 - 1s - loss: 1.0609e-04 - 602ms/epoch - 25ms/step
# Epoch 81/200
# 24/24 - 1s - loss: 1.0676e-04 - 583ms/epoch - 24ms/step
# Epoch 82/200
# 24/24 - 1s - loss: 9.8555e-05 - 620ms/epoch - 26ms/step
# Epoch 83/200
# 24/24 - 1s - loss: 1.0221e-04 - 586ms/epoch - 24ms/step
# Epoch 84/200
# 24/24 - 1s - loss: 1.0127e-04 - 601ms/epoch - 25ms/step
# Epoch 85/200
# 24/24 - 1s - loss: 1.0256e-04 - 617ms/epoch - 26ms/step
# Epoch 86/200
# 24/24 - 1s - loss: 8.6829e-05 - 617ms/epoch - 26ms/step
# Epoch 87/200
# 24/24 - 1s - loss: 1.0087e-04 - 626ms/epoch - 26ms/step
# Epoch 88/200
# 24/24 - 1s - loss: 1.0279e-04 - 622ms/epoch - 26ms/step
# Epoch 89/200
# 24/24 - 1s - loss: 9.4077e-05 - 624ms/epoch - 26ms/step
# Epoch 90/200
# 24/24 - 1s - loss: 8.8556e-05 - 630ms/epoch - 26ms/step
# Epoch 91/200
# 24/24 - 1s - loss: 1.1361e-04 - 602ms/epoch - 25ms/step
# Epoch 92/200
# 24/24 - 1s - loss: 9.1660e-05 - 617ms/epoch - 26ms/step
# Epoch 93/200
# 24/24 - 1s - loss: 8.2158e-05 - 601ms/epoch - 25ms/step
# Epoch 94/200
# 24/24 - 1s - loss: 8.1671e-05 - 601ms/epoch - 25ms/step
# Epoch 95/200
# 24/24 - 1s - loss: 8.5692e-05 - 595ms/epoch - 25ms/step
# Epoch 96/200
# 24/24 - 1s - loss: 9.4076e-05 - 585ms/epoch - 24ms/step
# Epoch 97/200
# 24/24 - 1s - loss: 9.9339e-05 - 601ms/epoch - 25ms/step
# Epoch 98/200
# 24/24 - 1s - loss: 9.9704e-05 - 586ms/epoch - 24ms/step
# Epoch 99/200
# 24/24 - 1s - loss: 8.4941e-05 - 602ms/epoch - 25ms/step
# Epoch 100/200
# 24/24 - 1s - loss: 8.3108e-05 - 601ms/epoch - 25ms/step
# Epoch 101/200
# 24/24 - 1s - loss: 8.2994e-05 - 639ms/epoch - 27ms/step
# Epoch 102/200
# 24/24 - 1s - loss: 8.3638e-05 - 602ms/epoch - 25ms/step
# Epoch 103/200
# 24/24 - 1s - loss: 7.7796e-05 - 602ms/epoch - 25ms/step
# Epoch 104/200
# 24/24 - 1s - loss: 7.3962e-05 - 619ms/epoch - 26ms/step
# Epoch 105/200
# 24/24 - 1s - loss: 7.0488e-05 - 598ms/epoch - 25ms/step
# Epoch 106/200
# 24/24 - 1s - loss: 7.5822e-05 - 601ms/epoch - 25ms/step
# Epoch 107/200
# 24/24 - 1s - loss: 8.6543e-05 - 601ms/epoch - 25ms/step
# Epoch 108/200
# 24/24 - 1s - loss: 7.3423e-05 - 602ms/epoch - 25ms/step
# Epoch 109/200
# 24/24 - 1s - loss: 6.8076e-05 - 601ms/epoch - 25ms/step
# Epoch 110/200
# 24/24 - 1s - loss: 6.9854e-05 - 601ms/epoch - 25ms/step
# Epoch 111/200
# 24/24 - 1s - loss: 7.6605e-05 - 601ms/epoch - 25ms/step
# Epoch 112/200
# 24/24 - 1s - loss: 6.9188e-05 - 602ms/epoch - 25ms/step
# Epoch 113/200
# 24/24 - 1s - loss: 7.7792e-05 - 585ms/epoch - 24ms/step
# Epoch 114/200
# 24/24 - 1s - loss: 7.7605e-05 - 595ms/epoch - 25ms/step
# Epoch 115/200
# 24/24 - 1s - loss: 8.3947e-05 - 586ms/epoch - 24ms/step
# Epoch 116/200
# 24/24 - 1s - loss: 9.7030e-05 - 595ms/epoch - 25ms/step
# Epoch 117/200
# 24/24 - 1s - loss: 1.3242e-04 - 585ms/epoch - 24ms/step
# Epoch 118/200
# 24/24 - 1s - loss: 7.7375e-05 - 593ms/epoch - 25ms/step
# Epoch 119/200
# 24/24 - 1s - loss: 7.1566e-05 - 586ms/epoch - 24ms/step
# Epoch 120/200
# 24/24 - 1s - loss: 6.8367e-05 - 585ms/epoch - 24ms/step
# Epoch 121/200
# 24/24 - 1s - loss: 7.5214e-05 - 586ms/epoch - 24ms/step
# Epoch 122/200
# 24/24 - 1s - loss: 7.1370e-05 - 601ms/epoch - 25ms/step
# Epoch 123/200
# 24/24 - 1s - loss: 7.5059e-05 - 579ms/epoch - 24ms/step
# Epoch 124/200
# 24/24 - 1s - loss: 7.1843e-05 - 601ms/epoch - 25ms/step
# Epoch 125/200
# 24/24 - 1s - loss: 7.3662e-05 - 591ms/epoch - 25ms/step
# Epoch 126/200
# 24/24 - 1s - loss: 8.5189e-05 - 596ms/epoch - 25ms/step
# Epoch 127/200
# 24/24 - 1s - loss: 7.2600e-05 - 601ms/epoch - 25ms/step
# Epoch 128/200
# 24/24 - 1s - loss: 7.1473e-05 - 586ms/epoch - 24ms/step
# Epoch 129/200
# 24/24 - 1s - loss: 7.5636e-05 - 586ms/epoch - 24ms/step
# Epoch 130/200
# 24/24 - 1s - loss: 6.9650e-05 - 585ms/epoch - 24ms/step
# Epoch 131/200
# 24/24 - 1s - loss: 6.1519e-05 - 601ms/epoch - 25ms/step
# Epoch 132/200
# 24/24 - 1s - loss: 6.8618e-05 - 607ms/epoch - 25ms/step
# Epoch 133/200
# 24/24 - 1s - loss: 6.4123e-05 - 592ms/epoch - 25ms/step
# Epoch 134/200
# 24/24 - 1s - loss: 6.3018e-05 - 603ms/epoch - 25ms/step
# Epoch 135/200
# 24/24 - 1s - loss: 8.2643e-05 - 585ms/epoch - 24ms/step
# Epoch 136/200
# 24/24 - 1s - loss: 6.2860e-05 - 601ms/epoch - 25ms/step
# Epoch 137/200
# 24/24 - 1s - loss: 7.1221e-05 - 586ms/epoch - 24ms/step
# Epoch 138/200
# 24/24 - 1s - loss: 6.5321e-05 - 601ms/epoch - 25ms/step
# Epoch 139/200
# 24/24 - 1s - loss: 7.0517e-05 - 586ms/epoch - 24ms/step
# Epoch 140/200
# 24/24 - 1s - loss: 6.0604e-05 - 586ms/epoch - 24ms/step
# Epoch 141/200
# 24/24 - 1s - loss: 7.8273e-05 - 593ms/epoch - 25ms/step
# Epoch 142/200
# 24/24 - 1s - loss: 6.2923e-05 - 580ms/epoch - 24ms/step
# Epoch 143/200
# 24/24 - 1s - loss: 6.6675e-05 - 593ms/epoch - 25ms/step
# Epoch 144/200
# 24/24 - 1s - loss: 6.6993e-05 - 586ms/epoch - 24ms/step
# Epoch 145/200
# 24/24 - 1s - loss: 6.4405e-05 - 586ms/epoch - 24ms/step
# Epoch 146/200
# 24/24 - 1s - loss: 6.5302e-05 - 601ms/epoch - 25ms/step
# Epoch 147/200
# 24/24 - 1s - loss: 5.9337e-05 - 602ms/epoch - 25ms/step
# Epoch 148/200
# 24/24 - 1s - loss: 6.1590e-05 - 601ms/epoch - 25ms/step
# Epoch 149/200
# 24/24 - 1s - loss: 5.9492e-05 - 604ms/epoch - 25ms/step
# Epoch 150/200
# 24/24 - 1s - loss: 6.2599e-05 - 582ms/epoch - 24ms/step
# Epoch 151/200
# 24/24 - 1s - loss: 8.4045e-05 - 602ms/epoch - 25ms/step
# Epoch 152/200
# 24/24 - 1s - loss: 7.6308e-05 - 617ms/epoch - 26ms/step
# Epoch 153/200
# 24/24 - 1s - loss: 6.7741e-05 - 608ms/epoch - 25ms/step
# Epoch 154/200
# 24/24 - 1s - loss: 6.0523e-05 - 586ms/epoch - 24ms/step
# Epoch 155/200
# 24/24 - 1s - loss: 5.6764e-05 - 586ms/epoch - 24ms/step
# Epoch 156/200
# 24/24 - 1s - loss: 6.0063e-05 - 586ms/epoch - 24ms/step
# Epoch 157/200
# 24/24 - 1s - loss: 6.5727e-05 - 596ms/epoch - 25ms/step
# Epoch 158/200
# 24/24 - 1s - loss: 5.8383e-05 - 607ms/epoch - 25ms/step
# Epoch 159/200
# 24/24 - 1s - loss: 6.9163e-05 - 585ms/epoch - 24ms/step
# Epoch 160/200
# 24/24 - 1s - loss: 6.0442e-05 - 594ms/epoch - 25ms/step
# Epoch 161/200
# 24/24 - 1s - loss: 7.4479e-05 - 579ms/epoch - 24ms/step
# Epoch 162/200
# 24/24 - 1s - loss: 6.5828e-05 - 586ms/epoch - 24ms/step
# Epoch 163/200
# 24/24 - 1s - loss: 6.2084e-05 - 586ms/epoch - 24ms/step
# Epoch 164/200
# 24/24 - 1s - loss: 6.1803e-05 - 585ms/epoch - 24ms/step
# Epoch 165/200
# 24/24 - 1s - loss: 5.6239e-05 - 602ms/epoch - 25ms/step
# Epoch 166/200
# 24/24 - 1s - loss: 7.5691e-05 - 584ms/epoch - 24ms/step
# Epoch 167/200
# 24/24 - 1s - loss: 6.6715e-05 - 585ms/epoch - 24ms/step
# Epoch 168/200
# 24/24 - 1s - loss: 6.3836e-05 - 579ms/epoch - 24ms/step
# Epoch 169/200
# 24/24 - 1s - loss: 6.3137e-05 - 601ms/epoch - 25ms/step
# Epoch 170/200
# 24/24 - 1s - loss: 6.0607e-05 - 585ms/epoch - 24ms/step
# Epoch 171/200
# 24/24 - 1s - loss: 5.4860e-05 - 586ms/epoch - 24ms/step
# Epoch 172/200
# 24/24 - 1s - loss: 6.1393e-05 - 601ms/epoch - 25ms/step
# Epoch 173/200
# 24/24 - 1s - loss: 6.4417e-05 - 617ms/epoch - 26ms/step
# Epoch 174/200
# 24/24 - 1s - loss: 5.6963e-05 - 591ms/epoch - 25ms/step
# Epoch 175/200
# 24/24 - 1s - loss: 5.6565e-05 - 596ms/epoch - 25ms/step
# Epoch 176/200
# 24/24 - 1s - loss: 5.7860e-05 - 601ms/epoch - 25ms/step
# Epoch 177/200
# 24/24 - 1s - loss: 6.8652e-05 - 601ms/epoch - 25ms/step
# Epoch 178/200
# 24/24 - 1s - loss: 7.3051e-05 - 586ms/epoch - 24ms/step
# Epoch 179/200
# 24/24 - 1s - loss: 6.9045e-05 - 601ms/epoch - 25ms/step
# Epoch 180/200
# 24/24 - 1s - loss: 5.8570e-05 - 602ms/epoch - 25ms/step
# Epoch 181/200
# 24/24 - 1s - loss: 5.3464e-05 - 586ms/epoch - 24ms/step
# Epoch 182/200
# 24/24 - 1s - loss: 5.3474e-05 - 597ms/epoch - 25ms/step
# Epoch 183/200
# 24/24 - 1s - loss: 6.0309e-05 - 590ms/epoch - 25ms/step
# Epoch 184/200
# 24/24 - 1s - loss: 5.8431e-05 - 579ms/epoch - 24ms/step
# Epoch 185/200
# 24/24 - 1s - loss: 6.2481e-05 - 585ms/epoch - 24ms/step
# Epoch 186/200
# 24/24 - 1s - loss: 6.7402e-05 - 585ms/epoch - 24ms/step
# Epoch 187/200
# 24/24 - 1s - loss: 5.3981e-05 - 585ms/epoch - 24ms/step
# Epoch 188/200
# 24/24 - 1s - loss: 5.6008e-05 - 601ms/epoch - 25ms/step
# Epoch 189/200
# 24/24 - 1s - loss: 5.4802e-05 - 586ms/epoch - 24ms/step
# Epoch 190/200
# 24/24 - 1s - loss: 7.0788e-05 - 586ms/epoch - 24ms/step
# Epoch 191/200
# 24/24 - 1s - loss: 6.2955e-05 - 586ms/epoch - 24ms/step
# Epoch 192/200
# 24/24 - 1s - loss: 6.2410e-05 - 587ms/epoch - 24ms/step
# Epoch 193/200
# 24/24 - 1s - loss: 6.0645e-05 - 579ms/epoch - 24ms/step
# Epoch 194/200
# 24/24 - 1s - loss: 5.4089e-05 - 601ms/epoch - 25ms/step
# Epoch 195/200
# 24/24 - 1s - loss: 5.3117e-05 - 617ms/epoch - 26ms/step
# Epoch 196/200
# 24/24 - 1s - loss: 5.2100e-05 - 608ms/epoch - 25ms/step
# Epoch 197/200
# 24/24 - 1s - loss: 5.4884e-05 - 648ms/epoch - 27ms/step
# Epoch 198/200
# 24/24 - 1s - loss: 6.0081e-05 - 615ms/epoch - 26ms/step
# Epoch 199/200
# 24/24 - 1s - loss: 5.9163e-05 - 611ms/epoch - 25ms/step
# Epoch 200/200
# 24/24 - 1s - loss: 7.7327e-05 - 611ms/epoch - 25ms/step

# %% [markdown]
# # Xây dựng tập thử nghiệm test

# %%
#tạo tập dữ liệu test với timestep=60 ngày tương tự như tập train
testingData = scaledData[trainingDataLength - 60: , :]

#tạo tập Xtest và Ytest
Xtest = []
Ytest = stock_close_dataset[trainingDataLength:, :]
for i in range(60, len(testingData)):
  Xtest.append(testingData[i-60:i, 0])

# %%
#chuyển dữ liệu Xtest thành mảng numpy
Xtest = np.array(Xtest)
Xtest
# Out:
# array([[0.47342888, 0.47976576, 0.47846818, ..., 0.46067191, 0.4570843 ,
#         0.45422715],
#        [0.47976576, 0.47846818, 0.46875944, ..., 0.4570843 , 0.45422715,
#         0.44799815],
#        [0.47846818, 0.46875944, 0.47329327, ..., 0.45422715, 0.44799815,
#         0.45142549],
#        ...,
#        [0.89324087, 0.89640623, 0.88799199, ..., 0.91322238, 0.8919063 ,
#         0.89614733],
#        [0.89640623, 0.88799199, 0.90403144, ..., 0.8919063 , 0.89614733,
#         0.88536909],
#        [0.88799199, 0.90403144, 0.8989305 , ..., 0.89614733, 0.88536909,
#         0.85381723]])

# %%
#Reshape dữ liệu 
Xtest = np.reshape(Xtest, (Xtest.shape[0], Xtest.shape[1], 1 ))

# %%
#Chuyển đổi về dạng giá thông thường mà ta đọc được 
predictions = model.predict(Xtest)
predictions = scaler.inverse_transform(predictions)
predictions
# Out:
# 10/10 [==============================] - 1s 12ms/step
# array([[1708.8907],
#        [1691.7102],
#        [1699.6345],
#        [1701.6305],
#        [1694.1709],
#        [1701.0509],
#        [1712.6862],
#        [1715.1836],
#        [1721.6586],
#        [1740.2489],
#        [1737.1691],
#        [1741.8842],
#        [1737.0507],
#        [1741.0085],
#        [1738.5554],
#        [1806.3254],
#        [1819.9935],
#        [1798.6912],
#        [1793.0494],
#        [1835.4508],
#        [1822.9591],
#        [1843.622 ],
#        [1850.4591],
#        [1837.5048],
#        [1842.8557],
#        [1828.5687],
#        [1833.8977],
#        [1816.8013],
#        [1808.2743],
#        [1822.3156],
#        [1814.371 ],
#        [1837.0526],
#        [1837.0067],
#        [1833.1953],
#        [1811.5126],
#        [1778.521 ],
#        [1795.7845],
#        [1805.2131],
#        [1818.3514],
#        [1942.1168],
#        [1956.4868],
#        [1991.3263],
#        [1980.8832],
#        [1983.3655],
#        [2007.9429],
#        [2060.6335],
#        [2081.3223],
#        [2089.2466],
#        [2078.0398],
#        [2061.5996],
#        [2080.291 ],
#        [2097.807 ],
#        [2084.148 ],
#        [2029.0558],
#        [1944.2007],
#        [1906.0885],
#        [1915.2025],
#        [1836.5598],
#        [1829.8452],
#        [1897.0203],
#        [1869.0938],
#        [1922.4379],
#        [1881.5667],
#        [1850.7063],
#        [1756.0015],
#        [1822.4543],
#        [1775.9318],
#        [1643.8955],
#        [1715.7924],
#        [1655.4575],
#        [1745.3107],
#        [1785.0469],
#        [1832.1941],
#        [1804.7147],
#        [1842.8656],
#        [1879.4395],
#        [1833.6996],
#        [1884.2479],
#        [1843.6749],
#        [1892.507 ],
#        [1889.0819],
#        [1850.2114],
#        [1854.6112],
#        [1847.0563],
#        [1928.9905],
#        [1955.6425],
#        [1984.3865],
#        [1984.1185],
#        [2096.3665],
#        [2214.99  ],
#        [2242.3035],
#        [2330.637 ],
#        [2294.5293],
#        [2302.0222],
#        [2234.4058],
#        [2266.9573],
#        [2309.1797],
#        [2325.26  ],
#        [2292.1816],
#        [2229.151 ],
#        [2287.283 ],
#        [2395.7305],
#        [2210.0366],
#        [2230.523 ],
#        [2236.2432],
#        [2273.371 ],
#        [2292.4778],
#        [2303.4033],
#        [2330.0574],
#        [2275.055 ],
#        [2281.0325],
#        [2302.0295],
#        [2324.056 ],
#        [2340.3748],
#        [2362.0684],
#        [2409.4712],
#        [2354.7917],
#        [2340.2886],
#        [2324.5432],
#        [2314.555 ],
#        [2307.5703],
#        [2351.8135],
#        [2383.6367],
#        [2384.2937],
#        [2387.261 ],
#        [2366.328 ],
#        [2387.4126],
#        [2429.6433],
#        [2508.5496],
#        [2553.8296],
#        [2452.5444],
#        [2434.4097],
#        [2463.7634],
#        [2511.441 ],
#        [2539.2097],
#        [2550.5732],
#        [2569.335 ],
#        [2607.0676],
#        [2656.9895],
#        [2618.3982],
#        [2637.2104],
#        [2567.553 ],
#        [2557.5693],
#        [2645.735 ],
#        [2775.5654],
#        [2778.3047],
#        [2953.1997],
#        [2864.1594],
#        [2950.058 ],
#        [3048.3215],
#        [3049.9497],
#        [2928.587 ],
#        [2915.2627],
#        [2833.4336],
#        [2840.964 ],
#        [2805.9082],
#        [3086.1592],
#        [2988.922 ],
#        [2946.1892],
#        [2810.766 ],
#        [2852.6465],
#        [2906.6504],
#        [2841.8591],
#        [2886.8865],
#        [2902.414 ],
#        [3028.8433],
#        [2947.5813],
#        [2980.4214],
#        [3047.257 ],
#        [3058.048 ],
#        [2983.1665],
#        [2966.6587],
#        [2891.1833],
#        [3001.0479],
#        [2990.8115],
#        [2977.7483],
#        [3017.45  ],
#        [3162.9194],
#        [3076.1582],
#        [3123.3271],
#        [3094.3208],
#        [3122.7007],
#        [3162.776 ],
#        [3268.4238],
#        [3195.282 ],
#        [3202.4023],
#        [3256.0842],
#        [3303.5342],
#        [3330.2256],
#        [3119.1528],
#        [3068.0083],
#        [2911.1714],
#        [3094.6294],
#        [2969.3699],
#        [2926.1792],
#        [2920.3252],
#        [2989.262 ],
#        [2891.3442],
#        [2823.4336],
#        [2771.7456],
#        [2790.6045],
#        [2988.168 ],
#        [2818.9248],
#        [2855.5518],
#        [2934.4282],
#        [3016.085 ],
#        [2966.8945],
#        [2969.647 ],
#        [3049.1614],
#        [2924.5513],
#        [3026.4065],
#        [2898.6897],
#        [3030.3499],
#        [3010.2627],
#        [3126.0518],
#        [3290.4858],
#        [3256.5217],
#        [3150.1   ],
#        [3127.8723],
#        [3053.3381],
#        [2994.6987],
#        [3025.537 ],
#        [2993.2732],
#        [2995.0525],
#        [3031.716 ],
#        [3031.1782],
#        [3123.096 ],
#        [2958.9106],
#        [3035.725 ],
#        [2819.0676],
#        [2817.935 ],
#        [2878.0051],
#        [3104.4055],
#        [3171.0159],
#        [3134.906 ],
#        [2924.2808],
#        [2821.5002],
#        [2961.8223],
#        [2925.8958],
#        [2958.5125],
#        [2957.865 ],
#        [2963.0747],
#        [2925.9534],
#        [2943.5933],
#        [2921.5862],
#        [2924.3086],
#        [2947.8333],
#        [3023.3965],
#        [3023.816 ],
#        [2986.7666],
#        [3048.138 ],
#        [3018.4136],
#        [3001.0862],
#        [2974.4775],
#        [2974.8115],
#        [3000.5393],
#        [2914.105 ],
#        [2924.691 ],
#        [2944.4028],
#        [2992.7659],
#        [2996.099 ],
#        [3081.1687],
#        [3058.7097],
#        [3014.632 ],
#        [3021.5967],
#        [3020.8154],
#        [2997.2969],
#        [2987.338 ],
#        [3121.6072],
#        [3147.8794],
#        [3094.9639],
#        [3061.165 ],
#        [2980.676 ],
#        [3033.7173],
#        [2937.3345],
#        [2984.642 ],
#        [3006.9548],
#        [2926.4983],
#        [2945.7761],
#        [2997.7158],
#        [2947.273 ],
#        [2925.5225],
#        [2947.2126],
#        [3111.93  ],
#        [3139.1162],
#        [3107.6057],
#        [3103.0422],
#        [3135.8955],
#        [3017.2803],
#        [3042.289 ],
#        [3005.9639],
#        [3179.3455],
#        [3199.7263],
#        [3109.7263],
#        [3138.5825],
#        [3156.961 ],
#        [3118.9043],
#        [3103.0454],
#        [3084.695 ],
#        [3061.338 ],
#        [3086.9456],
#        [3075.3594],
#        [3125.5625],
#        [3140.1167],
#        [3041.1484],
#        [2972.4924],
#        [3002.533 ],
#        [2963.9756],
#        [2855.2043]], dtype=float32)

# %%
#vẽ biểu đồ để biễu diễn dự đoán 
#chia tệp data thành tập train và reality sau đó xây dựng tệp predictions để so sánh 
training = stock_close_data[:trainingDataLength]
reality= stock_close_data[trainingDataLength:]
reality['Predictions'] = predictions

root = tkinter.Tk()
fig = mtlplt.figure(figsize=(20,10))
mtlplt.title('AMZN')
mtlplt.xlabel('Date', fontsize=20)
mtlplt.ylabel('Close Stock Price $ (VND)', fontsize=20)
mtlplt.plot(training['Close'])
mtlplt.plot(reality[['Close', 'Predictions']])
mtlplt.legend(['Training', 'Reality', 'Predictions'], loc='lower right')
canvas = FigureCanvasTkAgg(fig, master=root) 
canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

toolbar = NavigationToolbar2Tk(canvas, root)
toolbar.update()
canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

root.geometry('1400x900')
root.mainloop()

# %%
#Show dữ liệu Close và Predictions
reality
# Out:
#               Close  Predictions
# Date
# 2019-12-05  1740.48  1708.890747
# 2019-12-06  1751.60  1691.710205
# 2019-12-09  1749.51  1699.634521
# 2019-12-10  1739.21  1701.630493
# 2019-12-11  1748.72  1694.170898
# ...             ...          ...
# 2021-02-22  3180.74  3041.148438
# 2021-02-23  3194.50  2972.492432
# 2021-02-24  3159.53  3002.532959
# 2021-02-25  3057.16  2963.975586
# 2021-02-26  3092.93  2855.204346
#
# [309 rows x 2 columns]

# %%
#In kết quả của giá đóng và giá dự đoán ra file csv
reality.to_csv('AMZN_Ketquadubao.csv')

# %%
mae = np.mean(np.abs(Ytest - predictions ))
print(mae)
rmse = np.sqrt(np.mean((Ytest - predictions) ** 2))
print(rmse)
#tính độ chính xác của dự báo
mape = np.mean(np.abs((Ytest - predictions )/ Ytest)) *100
print(mape)
# Out:
# 134.37796833914845
# 154.8476913605858
# 4.761501634671841
