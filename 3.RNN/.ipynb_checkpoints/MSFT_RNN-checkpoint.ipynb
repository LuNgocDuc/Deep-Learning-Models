# %% [markdown]
# DỰ ĐOÁN GIÁ CỔ PHIẾU VỚI RNN

# %% [markdown]
# * [1. Loading Data](#1) <br>
# * [2.Spliting Data as Train and Validation](#2) <br>
# * [3.Creating Train Dataset from Train split](#3) <br>
# * [4.Normalization / Feature Scaling](#4) <br>
# * [5.Creating X_train and y_train from Train data](#5) <br>
# * [6.Creating Simple RNN model](#6) <br>
# * [7.Evaluating Model](#7) <br>
# * [8.Creating Test Dataset from Validation Data](#8) <br>
# * [9.Evaluating with Validation Data](#9) <br>
# * [10.Creating LSTM model](#10) <br>
# * [11.Evaluating LSTM model](#11) <br>
# * [12.Future price prediction](#12) <br>

# %% [markdown]
# <a id="1"></a>
# ## 1.Loading Data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# %%
data = pd.read_csv("./Database/Pre_Processed_AMZN.csv")

# %%
data.head()
# Out:
#        Date    Open    High     Low   Close  Adj. Close     Volume
# 0  1/4/2010  6.8125  6.8305  6.6570  6.6950      6.6950  151998000
# 1  1/5/2010  6.6715  6.7740  6.5905  6.7345      6.7345  177038000
# 2  1/6/2010  6.7300  6.7365  6.5825  6.6125      6.6125  143576000
# 3  1/7/2010  6.6005  6.6160  6.4400  6.5000      6.5000  220604000
# 4  1/8/2010  6.5280  6.6840  6.4515  6.6760      6.6760  196610000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2767 entries, 0 to 2766
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2767 non-null   object
#  1   Open        2767 non-null   float64
#  2   High        2767 non-null   float64
#  3   Low         2767 non-null   float64
#  4   Close       2767 non-null   float64
#  5   Adj. Close  2767 non-null   float64
#  6   Volume      2767 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 151.4+ KB

# %% [markdown]
# <a id="2"></a>
# ## 2.Spliting Data as Train and Validation

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.8          # %80 train + %20 validation
length_train = round(length_data * split_ratio)  
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 2767
# Train data length : 2214
# Validation data lenth : 553

# %%
train_data = data[:length_train].iloc[:,:6] 
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#            Date       Open       High        Low      Close  Adj. Close
# 0    2010-01-04   6.812500   6.830500   6.657000   6.695000    6.695000
# 1    2010-01-05   6.671500   6.774000   6.590500   6.734500    6.734500
# 2    2010-01-06   6.730000   6.736500   6.582500   6.612500    6.612500
# 3    2010-01-07   6.600500   6.616000   6.440000   6.500000    6.500000
# 4    2010-01-08   6.528000   6.684000   6.451500   6.676000    6.676000
# ...         ...        ...        ...        ...        ...         ...
# 2209 2018-10-11  86.199997  87.769997  84.254997  85.968002   85.968002
# 2210 2018-10-12  90.400002  90.447502  87.126503  89.430496   89.430496
# 2211 2018-10-15  89.750000  89.752502  86.711502  88.047501   88.047501
# 2212 2018-10-16  89.175003  91.194000  88.077499  90.998001   90.998001
# 2213 2018-10-17  92.139503  92.250000  90.349998  91.586502   91.586502
#
# [2214 rows x 6 columns]

# %%
validation_data = data[length_train:].iloc[:,:6]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#            Date        Open        High         Low       Close  Adj. Close
# 2214 2018-10-18   91.074501   91.507500   88.393501   88.536003   88.536003
# 2215 2018-10-19   89.258003   90.455002   87.650002   88.201500   88.201500
# 2216 2018-10-22   89.199997   90.474998   87.800003   89.464996   89.464996
# 2217 2018-10-23   87.112000   88.817001   85.699997   88.434998   88.434998
# 2218 2018-10-24   88.684998   88.885498   82.828003   83.209999   83.209999
# ...         ...         ...         ...         ...         ...         ...
# 2762 2020-12-22  160.141998  161.100006  159.003998  160.326004  160.326004
# 2763 2020-12-23  160.250000  160.506500  159.208496  159.263504  159.263504
# 2764 2020-12-24  159.695007  160.100006  158.449997  158.634506  158.634506
# 2765 2020-12-28  159.699997  165.199997  158.634506  164.197998  164.197998
# 2766 2020-12-29  165.496994  167.532501  164.061005  166.100006  166.100006
#
# [553 rows x 6 columns]

# %% [markdown]
# <a id="3"></a>
# ## 3.Creating Train Dataset from Train split

# %% [markdown]
# * We will get Open column as our dataset
# * Dataset to be converted to array by adding `.values`

# %%
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (2214,)

# %%
# Change 1d array to 2d array
# Changing shape from (1692,) to (1692,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (2214, 1)

# %% [markdown]
# #### <a id="4"></a>
# ## 4.Normalization / Feature Scaling

# %% [markdown]
# * Dataset values will be in between 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (2214, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days as 1st, 2nd, 3rd..")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# <a id="5"></a>
# ## 5.Creating X_train and y_train from Train data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * We have train data composed of stock open prices over days
# * So, it has 1184 prices corresponding 1184 days
# * My aim is to predict the open price of the next day.
# * I can use a time step of 50 days.
# * I will pick first 50 open prices (0 to 50), 1st 50 price will be in X_train data
# * Then predict the price of 51th day; and 51th price will be in y_train data
# * Again, i will pick prices from 1 to 51, those will be in X_train data
# * Then predict the next days price, 52nd price will be in y_train data

# %%
X_train = []
y_train = []

time_step = 7

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])
    
# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (2207, 7)
# Shape of y_train before reshape : (2207,)

# %% [markdown]
# ## Reshape

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (2207, 7, 1)
# Shape of y_train after reshape : (2207, 1)

# %% [markdown]
# * Shape of X_train : 1134 x 50 x 1
# * That means we have 1134 rows, each row has 50 rows and 1 column
# * Lets check the first row: it has 50 rows (open prices of 49 days)

# %%
X_train[0]
# Out:
# array([[0.01569212],
#        [0.01423263],
#        [0.01483816],
#        [0.01349771],
#        [0.01274726],
#        [0.01381341],
#        [0.0119347 ]])

# %% [markdown]
# * Check the first item in y_train
# * It is the price of 50th day

# %%
y_train[0]
# Out:
# array([0.01137057])

# %% [markdown]
# <a id="6"></a>
# ## 6.Creating RNN model

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True, 
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam", 
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 200, batch_size = 32)
# Out:
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Win10\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 69/69 [==============================] - 4s 6ms/step - loss: 0.1117 - accuracy: 9.0621e-04
# Epoch 2/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0374 - accuracy: 9.0621e-04
# Epoch 3/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0259 - accuracy: 9.0621e-04
# Epoch 4/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 4.5310e-04
# Epoch 5/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 9.0621e-04
# Epoch 6/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 9.0621e-04
# Epoch 7/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 9.0621e-04
# Epoch 8/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 9.0621e-04
# Epoch 9/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 4.5310e-04
# Epoch 10/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 9.0621e-04
# Epoch 11/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 9.0621e-04
# Epoch 12/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 9.0621e-04
# Epoch 13/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 9.0621e-04
# Epoch 14/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 9.0621e-04
# Epoch 15/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 9.0621e-04
# Epoch 16/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 4.5310e-04
# Epoch 17/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 9.0621e-04
# Epoch 18/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 9.0621e-04
# Epoch 19/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 9.0621e-04
# Epoch 20/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 9.0621e-04
# Epoch 21/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 9.0621e-04
# Epoch 22/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 9.0621e-04
# Epoch 23/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 9.0621e-04
# Epoch 24/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 9.0621e-04
# Epoch 25/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 9.0621e-04
# Epoch 26/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 9.0621e-04
# Epoch 27/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 9.0621e-04
# Epoch 28/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 9.0621e-04
# Epoch 29/200
# 69/69 [==============================] - 1s 8ms/step - loss: 0.0019 - accuracy: 9.0621e-04
# Epoch 30/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 9.0621e-04
# Epoch 31/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 9.0621e-04
# Epoch 32/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 9.0621e-04
# Epoch 33/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 34/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 9.0621e-04
# Epoch 35/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 36/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 37/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 38/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 39/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 40/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 41/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 42/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 43/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 44/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 45/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 46/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 47/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 48/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 49/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 50/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 51/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 52/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 53/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 54/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.8187e-04 - accuracy: 9.0621e-04
# Epoch 55/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 56/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 57/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.1968e-04 - accuracy: 9.0621e-04
# Epoch 58/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.9399e-04 - accuracy: 9.0621e-04
# Epoch 59/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 60/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.5920e-04 - accuracy: 9.0621e-04
# Epoch 61/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.0770e-04 - accuracy: 9.0621e-04
# Epoch 62/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 63/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 64/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6140e-04 - accuracy: 9.0621e-04
# Epoch 65/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.8656e-04 - accuracy: 9.0621e-04
# Epoch 66/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 67/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9767e-04 - accuracy: 9.0621e-04
# Epoch 68/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.7925e-04 - accuracy: 9.0621e-04
# Epoch 69/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.0880e-04 - accuracy: 9.0621e-04
# Epoch 70/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.8692e-04 - accuracy: 9.0621e-04
# Epoch 71/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.7241e-04 - accuracy: 9.0621e-04
# Epoch 72/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8578e-04 - accuracy: 9.0621e-04
# Epoch 73/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7000e-04 - accuracy: 9.0621e-04
# Epoch 74/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9793e-04 - accuracy: 9.0621e-04
# Epoch 75/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9865e-04 - accuracy: 9.0621e-04
# Epoch 76/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1432e-04 - accuracy: 9.0621e-04
# Epoch 77/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1494e-04 - accuracy: 9.0621e-04
# Epoch 78/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8390e-04 - accuracy: 9.0621e-04
# Epoch 79/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6838e-04 - accuracy: 9.0621e-04
# Epoch 80/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9755e-04 - accuracy: 9.0621e-04
# Epoch 81/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1921e-04 - accuracy: 9.0621e-04
# Epoch 82/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1619e-04 - accuracy: 9.0621e-04
# Epoch 83/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4168e-04 - accuracy: 9.0621e-04
# Epoch 84/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6429e-04 - accuracy: 9.0621e-04
# Epoch 85/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0502e-04 - accuracy: 9.0621e-04
# Epoch 86/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5673e-04 - accuracy: 9.0621e-04
# Epoch 87/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4376e-04 - accuracy: 9.0621e-04
# Epoch 88/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1054e-04 - accuracy: 9.0621e-04
# Epoch 89/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5400e-04 - accuracy: 9.0621e-04
# Epoch 90/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7423e-04 - accuracy: 9.0621e-04
# Epoch 91/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0154e-04 - accuracy: 9.0621e-04
# Epoch 92/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0841e-04 - accuracy: 9.0621e-04
# Epoch 93/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.1391e-04 - accuracy: 9.0621e-04
# Epoch 94/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4951e-04 - accuracy: 9.0621e-04
# Epoch 95/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9994e-04 - accuracy: 9.0621e-04
# Epoch 96/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.3643e-04 - accuracy: 9.0621e-04
# Epoch 97/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3301e-04 - accuracy: 9.0621e-04
# Epoch 98/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7449e-04 - accuracy: 9.0621e-04
# Epoch 99/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7401e-04 - accuracy: 9.0621e-04
# Epoch 100/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5511e-04 - accuracy: 9.0621e-04
# Epoch 101/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.3111e-04 - accuracy: 9.0621e-04
# Epoch 102/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1826e-04 - accuracy: 9.0621e-04
# Epoch 103/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4440e-04 - accuracy: 9.0621e-04
# Epoch 104/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4920e-04 - accuracy: 9.0621e-04
# Epoch 105/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2612e-04 - accuracy: 9.0621e-04
# Epoch 106/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1196e-04 - accuracy: 9.0621e-04
# Epoch 107/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3562e-04 - accuracy: 9.0621e-04
# Epoch 108/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5382e-04 - accuracy: 9.0621e-04
# Epoch 109/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.3196e-04 - accuracy: 9.0621e-04
# Epoch 110/200
# 69/69 [==============================] - 0s 7ms/step - loss: 8.6126e-04 - accuracy: 9.0621e-04
# Epoch 111/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.2854e-04 - accuracy: 9.0621e-04
# Epoch 112/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5248e-04 - accuracy: 9.0621e-04
# Epoch 113/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0448e-04 - accuracy: 9.0621e-04
# Epoch 114/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.0087e-04 - accuracy: 9.0621e-04
# Epoch 115/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5830e-04 - accuracy: 9.0621e-04
# Epoch 116/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8547e-04 - accuracy: 9.0621e-04
# Epoch 117/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9716e-04 - accuracy: 9.0621e-04
# Epoch 118/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3192e-04 - accuracy: 9.0621e-04
# Epoch 119/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7887e-04 - accuracy: 9.0621e-04
# Epoch 120/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3853e-04 - accuracy: 9.0621e-04
# Epoch 121/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5637e-04 - accuracy: 9.0621e-04
# Epoch 122/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8468e-04 - accuracy: 9.0621e-04
# Epoch 123/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1840e-04 - accuracy: 9.0621e-04
# Epoch 124/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6346e-04 - accuracy: 9.0621e-04
# Epoch 125/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4852e-04 - accuracy: 9.0621e-04
# Epoch 126/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0627e-04 - accuracy: 9.0621e-04
# Epoch 127/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.9353e-04 - accuracy: 9.0621e-04
# Epoch 128/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5446e-04 - accuracy: 9.0621e-04
# Epoch 129/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9098e-04 - accuracy: 9.0621e-04
# Epoch 130/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4065e-04 - accuracy: 9.0621e-04
# Epoch 131/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8854e-04 - accuracy: 9.0621e-04
# Epoch 132/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.7890e-04 - accuracy: 9.0621e-04
# Epoch 133/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1062e-04 - accuracy: 9.0621e-04
# Epoch 134/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3543e-04 - accuracy: 9.0621e-04
# Epoch 135/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5902e-04 - accuracy: 9.0621e-04
# Epoch 136/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1583e-04 - accuracy: 9.0621e-04
# Epoch 137/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9593e-04 - accuracy: 9.0621e-04
# Epoch 138/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2740e-04 - accuracy: 9.0621e-04
# Epoch 139/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4157e-04 - accuracy: 9.0621e-04
# Epoch 140/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9227e-04 - accuracy: 9.0621e-04
# Epoch 141/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.7670e-04 - accuracy: 9.0621e-04
# Epoch 142/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6043e-04 - accuracy: 9.0621e-04
# Epoch 143/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2172e-04 - accuracy: 9.0621e-04
# Epoch 144/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5195e-04 - accuracy: 9.0621e-04
# Epoch 145/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0638e-04 - accuracy: 9.0621e-04
# Epoch 146/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4567e-04 - accuracy: 9.0621e-04
# Epoch 147/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9575e-04 - accuracy: 9.0621e-04
# Epoch 148/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4871e-04 - accuracy: 9.0621e-04
# Epoch 149/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 150/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9476e-04 - accuracy: 9.0621e-04
# Epoch 151/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2998e-04 - accuracy: 9.0621e-04
# Epoch 152/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7913e-04 - accuracy: 9.0621e-04
# Epoch 153/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1941e-04 - accuracy: 9.0621e-04
# Epoch 154/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3915e-04 - accuracy: 9.0621e-04
# Epoch 155/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8446e-04 - accuracy: 9.0621e-04
# Epoch 156/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.7182e-04 - accuracy: 9.0621e-04
# Epoch 157/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.8041e-04 - accuracy: 9.0621e-04
# Epoch 158/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4907e-04 - accuracy: 9.0621e-04
# Epoch 159/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4831e-04 - accuracy: 9.0621e-04
# Epoch 160/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7253e-04 - accuracy: 9.0621e-04
# Epoch 161/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9171e-04 - accuracy: 9.0621e-04
# Epoch 162/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4003e-04 - accuracy: 9.0621e-04
# Epoch 163/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6356e-04 - accuracy: 9.0621e-04
# Epoch 164/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6741e-04 - accuracy: 9.0621e-04
# Epoch 165/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4443e-04 - accuracy: 9.0621e-04
# Epoch 166/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.2260e-04 - accuracy: 9.0621e-04
# Epoch 167/200
# 69/69 [==============================] - 0s 7ms/step - loss: 7.1387e-04 - accuracy: 9.0621e-04
# Epoch 168/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9446e-04 - accuracy: 9.0621e-04
# Epoch 169/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0971e-04 - accuracy: 9.0621e-04
# Epoch 170/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8447e-04 - accuracy: 9.0621e-04
# Epoch 171/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.9600e-04 - accuracy: 9.0621e-04
# Epoch 172/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.7380e-04 - accuracy: 9.0621e-04
# Epoch 173/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6432e-04 - accuracy: 9.0621e-04
# Epoch 174/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4637e-04 - accuracy: 9.0621e-04
# Epoch 175/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8404e-04 - accuracy: 9.0621e-04
# Epoch 176/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3052e-04 - accuracy: 9.0621e-04
# Epoch 177/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8015e-04 - accuracy: 9.0621e-04
# Epoch 178/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3681e-04 - accuracy: 9.0621e-04
# Epoch 179/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3005e-04 - accuracy: 9.0621e-04
# Epoch 180/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1974e-04 - accuracy: 9.0621e-04
# Epoch 181/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2024e-04 - accuracy: 9.0621e-04
# Epoch 182/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4058e-04 - accuracy: 9.0621e-04
# Epoch 183/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6046e-04 - accuracy: 9.0621e-04
# Epoch 184/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0050e-04 - accuracy: 9.0621e-04
# Epoch 185/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9108e-04 - accuracy: 9.0621e-04
# Epoch 186/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.3348e-04 - accuracy: 9.0621e-04
# Epoch 187/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6943e-04 - accuracy: 9.0621e-04
# Epoch 188/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4389e-04 - accuracy: 9.0621e-04
# Epoch 189/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4174e-04 - accuracy: 9.0621e-04
# Epoch 190/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.7212e-04 - accuracy: 9.0621e-04
# Epoch 191/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.9706e-04 - accuracy: 9.0621e-04
# Epoch 192/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8880e-04 - accuracy: 9.0621e-04
# Epoch 193/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5510e-04 - accuracy: 9.0621e-04
# Epoch 194/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4802e-04 - accuracy: 9.0621e-04
# Epoch 195/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0363e-04 - accuracy: 9.0621e-04
# Epoch 196/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0421e-04 - accuracy: 9.0621e-04
# Epoch 197/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8209e-04 - accuracy: 9.0621e-04
# Epoch 198/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.9314e-04 - accuracy: 9.0621e-04
# Epoch 199/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0484e-04 - accuracy: 9.0621e-04
# Epoch 200/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7682e-04 - accuracy: 9.0621e-04

# %% [markdown]
# <a id="7"></a>
# ## 7.Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.11172855645418167,
#  0.03738091513514519,
#  0.025868218392133713,
#  0.0185187179595232,
#  0.015165721997618675,
#  0.010401307605206966,
#  0.008998028002679348,
#  0.00805475190281868,
#  0.007193536497652531,
#  0.005835054907947779,
#  0.005116675514727831,
#  0.0039253574796020985,
#  0.004551182966679335,
#  0.0043790871277451515,
#  0.0038465841207653284,
#  0.0032283912878483534,
#  0.0034902109764516354,
#  0.0029694808181375265,
#  0.0032340846955776215,
#  0.002728523686528206,
#  0.0029717423021793365,
#  0.0022904009092599154,
#  0.00257939868606627,
#  0.002506386488676071,
#  0.001942694652825594,
#  0.001823166268877685,
#  0.0018287113634869456,
#  0.0019723486620932817,
#  0.0019430750980973244,
#  0.001731471042148769,
#  0.0018187876557931304,
#  0.0017001575324684381,
#  0.0013163789408281446,
#  0.0016145628178492188,
#  0.001402591704390943,
#  0.0015479621943086386,
#  0.0014795932220295072,
#  0.001309409737586975,
#  0.0014025982236489654,
#  0.0012940963497385383,
#  0.0014290690887719393,
#  0.0012800039257854223,
#  0.0011715017026290298,
#  0.0013647278537973762,
#  0.001242713537067175,
#  0.0012528018560260534,
#  0.0010803466429933906,
#  0.001179692568257451,
#  0.001120621687732637,
#  0.0013587898574769497,
#  0.0010874138679355383,
#  0.0011748336255550385,
#  0.0010421263286843896,
#  0.000981867779046297,
#  0.0011127102188766003,
#  0.0010280032875016332,
#  0.000919679063372314,
#  0.0009939864976331592,
#  0.0010796505957841873,
#  0.0009591989801265299,
#  0.0009077019640244544,
#  0.0010463630314916372,
#  0.0010473185684531927,
#  0.0008614000398665667,
#  0.0009865558240562677,
#  0.0012203836813569069,
#  0.0008976686513051391,
#  0.0009792458731681108,
#  0.0009087991202250123,
#  0.0008869189186953008,
#  0.0009724114206619561,
#  0.000785775133408606,
#  0.0008700043545104563,
#  0.0008979297708719969,
#  0.0008986521861515939,
#  0.0008143240702338517,
#  0.000814942002762109,
#  0.0007839039317332208,
#  0.0007683829171583056,
#  0.0008975485106930137,
#  0.0008192135719582438,
#  0.0008161938167177141,
#  0.0008416842320002615,
#  0.0007642938871867955,
#  0.0008050160831771791,
#  0.0008567346958443522,
#  0.0007437583990395069,
#  0.000810536090284586,
#  0.0007540006190538406,
#  0.0007742310990579426,
#  0.0008015447529032826,
#  0.0008084126166068017,
#  0.0009139096364378929,
#  0.000849507749080658,
#  0.00089994230074808,
#  0.0008364292443729937,
#  0.0007330102380365133,
#  0.0007744883187115192,
#  0.000874008983373642,
#  0.0007551149465143681,
#  0.0009311064495705068,
#  0.0008182640885934234,
#  0.0008444013656117022,
#  0.000849200994707644,
#  0.0007261193823069334,
#  0.0008119596168398857,
#  0.0007356247515417635,
#  0.0008538161055184901,
#  0.0009319610544480383,
#  0.000861261913087219,
#  0.0009285410633310676,
#  0.000852480239700526,
#  0.000804480048827827,
#  0.0009008709457702935,
#  0.0007583015249110758,
#  0.0007854733848944306,
#  0.0008971590432338417,
#  0.0007319225696846843,
#  0.0007788688526488841,
#  0.0007385348435491323,
#  0.0008563723531551659,
#  0.0007846839725971222,
#  0.000718395400326699,
#  0.000763458723668009,
#  0.0008485224680043757,
#  0.0008062694105319679,
#  0.0006935254787094891,
#  0.0008544558077119291,
#  0.0007909763371571898,
#  0.0006406546453945339,
#  0.0007885396480560303,
#  0.0009788956958800554,
#  0.0008106239256449044,
#  0.0007354271947406232,
#  0.000859024643432349,
#  0.000715826521627605,
#  0.000795929750893265,
#  0.0008273988496512175,
#  0.0007415658328682184,
#  0.0007922739605419338,
#  0.0009766968432813883,
#  0.0007604266866110265,
#  0.0008217210415750742,
#  0.0007519520586356521,
#  0.0008063777931965888,
#  0.0007456658640876412,
#  0.0007957496563903987,
#  0.0007487131515517831,
#  0.0010200737742707133,
#  0.0007947575068101287,
#  0.0007299812859855592,
#  0.0007791329408064485,
#  0.0007194090285338461,
#  0.0007391459075734019,
#  0.0006844564341008663,
#  0.0006718217046000063,
#  0.0008804096141830087,
#  0.0007490723510272801,
#  0.0006483063334599137,
#  0.0007725326577201486,
#  0.0008917103987187147,
#  0.00074002705514431,
#  0.0008635577978566289,
#  0.0006674096221104264,
#  0.0006444306927733123,
#  0.0006225997931323946,
#  0.0007138749933801591,
#  0.0007944616372697055,
#  0.0008097101235762239,
#  0.0007844716892577708,
#  0.0006959997117519379,
#  0.0006738034426234663,
#  0.0008643151959404349,
#  0.0007463680813089013,
#  0.0006840441492386162,
#  0.0007305153994821012,
#  0.00068015290889889,
#  0.0007368115475401282,
#  0.0007300464203581214,
#  0.0008197350543923676,
#  0.000720237148925662,
#  0.0007405822980217636,
#  0.0006604579975828528,
#  0.0007004988729022443,
#  0.0007910789572633803,
#  0.0006334796780720353,
#  0.0006694327457807958,
#  0.0006438865093514323,
#  0.0006417389959096909,
#  0.0006721150712110102,
#  0.0006970605463720858,
#  0.000788803503382951,
#  0.0007550962036475539,
#  0.0006480218144133687,
#  0.0007036280003376305,
#  0.0008042120025493205,
#  0.0007820919854566455,
#  0.0006931445677764714,
#  0.0007048406405374408,
#  0.000776820583269]

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred = scaler.inverse_transform(y_pred) # scaling back from 0-1 to original
y_pred.shape
# Out:
# 69/69 [==============================] - 1s 3ms/step
# (2207, 1)

# %%
y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (2207, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# <a id="8"></a>
# ## 8.Creating Test Dataset from Validation Data

# %% [markdown]
# ### Converting array and scaling

# %%
dataset_validation = validation_data.Open.values  # getting "open" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling open values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (553, 1)

# %% [markdown]
# ### Creating X_test and y_test

# %%
# Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# ### Converting to array

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (546, 7)
# Shape of y_test before reshape : (546,)

# %% [markdown]
# ### Reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (546, 7, 1)
# Shape of y_test after reshape : (546, 1)

# %% [markdown]
# <a id="9"></a>
# ## 9.Evaluating with Validation Data

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test) 
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 18/18 [==============================] - 0s 3ms/step
# Shape of y_pred_of_test : (546, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
mae = np.mean(np.abs(scaler.inverse_transform(y_test) - y_pred_of_test ))
print(mae)
rmse = np.sqrt(np.mean((scaler.inverse_transform(y_test) - y_pred_of_test) ** 2))
print(rmse)
#tính độ chính xác của dự báo
mape = np.mean(np.abs((scaler.inverse_transform(y_test) - y_pred_of_test )/ scaler.inverse_transform(y_test))) *100
print(mape)
# Out:
# 3.3274993341403034
# 4.690421236774259
# 2.869365288304363

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.Open, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.Open, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()
