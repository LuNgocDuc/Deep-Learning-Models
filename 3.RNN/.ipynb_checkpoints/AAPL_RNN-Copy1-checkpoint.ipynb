# %% [markdown]
# DỰ ĐOÁN GIÁ CỔ PHIẾU VỚI RNN

# %% [markdown]
# * [1. Loading Data](#1) <br>
# * [2.Spliting Data as Train and Validation](#2) <br>
# * [3.Creating Train Dataset from Train split](#3) <br>
# * [4.Normalization / Feature Scaling](#4) <br>
# * [5.Creating X_train and y_train from Train data](#5) <br>
# * [6.Creating Simple RNN model](#6) <br>
# * [7.Evaluating Model](#7) <br>
# * [8.Creating Test Dataset from Validation Data](#8) <br>
# * [9.Evaluating with Validation Data](#9) <br>
# * [10.Creating LSTM model](#10) <br>
# * [11.Evaluating LSTM model](#11) <br>
# * [12.Future price prediction](#12) <br>

# %% [markdown]
# <a id="1"></a>
# ## 1.Loading Data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

# %%
data = pd.read_csv("./Database/Pre_Processed_AAPL.csv")

# %%
data.head()
# Out:
#        Date      Open      High       Low     Close  Adj. Close     Volume
# 0  1/4/2010  7.622500  7.660714  7.585000  7.643214    6.470741  493729600
# 1  1/5/2010  7.664286  7.699643  7.616071  7.656429    6.481928  601904800
# 2  1/6/2010  7.656429  7.686786  7.526786  7.534643    6.378826  552160000
# 3  1/7/2010  7.562500  7.571429  7.466071  7.520714    6.367033  477131200
# 4  1/8/2010  7.510714  7.571429  7.466429  7.570714    6.409364  447610800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2767 entries, 0 to 2766
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2767 non-null   object
#  1   Open        2767 non-null   float64
#  2   High        2767 non-null   float64
#  3   Low         2767 non-null   float64
#  4   Close       2767 non-null   float64
#  5   Adj. Close  2767 non-null   float64
#  6   Volume      2767 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 151.4+ KB

# %% [markdown]
# <a id="2"></a>
# ## 2.Spliting Data as Train and Validation

# %%
length_data = len(data)     # rows that data has
split_ratio = 0.8          # %80 train + %20 validation
length_train = round(length_data * split_ratio)  
length_validation = length_data - length_train
print("Data length :", length_data)
print("Train data length :", length_train)
print("Validation data lenth :", length_validation)
# Out:
# Data length : 2767
# Train data length : 2214
# Validation data lenth : 553

# %%
train_data = data[:length_train].iloc[:,:6] 
train_data['Date'] = pd.to_datetime(train_data['Date'])  # converting to date time object
train_data
# Out:
#            Date       Open       High        Low      Close  Adj. Close
# 0    2010-01-04   7.622500   7.660714   7.585000   7.643214    6.470741
# 1    2010-01-05   7.664286   7.699643   7.616071   7.656429    6.481928
# 2    2010-01-06   7.656429   7.686786   7.526786   7.534643    6.378826
# 3    2010-01-07   7.562500   7.571429   7.466071   7.520714    6.367033
# 4    2010-01-08   7.510714   7.571429   7.466429   7.570714    6.409364
# ...         ...        ...        ...        ...        ...         ...
# 2209 2018-10-11  53.630001  54.875000  53.080002  53.612499   51.213585
# 2210 2018-10-12  55.105000  55.720001  54.209999  55.527500   53.042896
# 2211 2018-10-15  55.290001  55.457500  54.317501  54.340000   51.908527
# 2212 2018-10-16  54.732498  55.747501  54.189999  55.537498   53.052448
# 2213 2018-10-17  55.575001  55.660000  54.834999  55.297501   52.823200
#
# [2214 rows x 6 columns]

# %%
validation_data = data[length_train:].iloc[:,:6]
validation_data['Date'] = pd.to_datetime(validation_data['Date'])  # converting to date time object
validation_data
# Out:
#            Date        Open        High         Low       Close  Adj. Close
# 2214 2018-10-18   54.465000   54.935001   53.250000   54.005001   51.588516
# 2215 2018-10-19   54.514999   55.314999   54.357498   54.827499   52.374222
# 2216 2018-10-22   54.947498   55.840000   54.735001   55.162498   52.694225
# 2217 2018-10-23   53.957500   55.812500   53.674999   55.682499   53.190968
# 2218 2018-10-24   55.650002   56.057499   53.634998   53.772499   51.366428
# ...         ...         ...         ...         ...         ...         ...
# 2762 2020-12-22  131.610001  134.410004  129.649994  131.880005  129.426132
# 2763 2020-12-23  132.160004  132.429993  130.779999  130.960007  128.523270
# 2764 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.514465
# 2765 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.146637
# 2766 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.360489
#
# [553 rows x 6 columns]

# %% [markdown]
# <a id="3"></a>
# ## 3.Creating Train Dataset from Train split

# %% [markdown]
# * We will get Open column as our dataset
# * Dataset to be converted to array by adding `.values`

# %%
dataset_train = train_data.Open.values
dataset_train.shape
# Out:
# (2214,)

# %%
# Change 1d array to 2d array
# Changing shape from (1692,) to (1692,1)
dataset_train = np.reshape(dataset_train, (-1,1))
dataset_train.shape
# Out:
# (2214, 1)

# %% [markdown]
# #### <a id="4"></a>
# ## 4.Normalization / Feature Scaling

# %% [markdown]
# * Dataset values will be in between 0 and 1 after scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))


# scaling dataset
dataset_train_scaled = scaler.fit_transform(dataset_train)

dataset_train_scaled.shape
# Out:
# (2214, 1)

# %%
plt.subplots(figsize = (15,6))
plt.plot(dataset_train_scaled)
plt.xlabel("Days as 1st, 2nd, 3rd..")
plt.ylabel("Open Price")
plt.show()

# %% [markdown]
# <a id="5"></a>
# ## 5.Creating X_train and y_train from Train data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * We have train data composed of stock open prices over days
# * So, it has 1184 prices corresponding 1184 days
# * My aim is to predict the open price of the next day.
# * I can use a time step of 50 days.
# * I will pick first 50 open prices (0 to 50), 1st 50 price will be in X_train data
# * Then predict the price of 51th day; and 51th price will be in y_train data
# * Again, i will pick prices from 1 to 51, those will be in X_train data
# * Then predict the next days price, 52nd price will be in y_train data

# %%
X_train = []
y_train = []

time_step = 7

for i in range(time_step, length_train):
    X_train.append(dataset_train_scaled[i-time_step:i,0])
    y_train.append(dataset_train_scaled[i,0])
    
# convert list to array
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print("Shape of X_train before reshape :",X_train.shape)
print("Shape of y_train before reshape :",y_train.shape)
# Out:
# Shape of X_train before reshape : (2207, 7)
# Shape of y_train before reshape : (2207,)

# %% [markdown]
# ## Reshape

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
y_train = np.reshape(y_train, (y_train.shape[0],1))

print("Shape of X_train after reshape :",X_train.shape)
print("Shape of y_train after reshape :",y_train.shape)
# Out:
# Shape of X_train after reshape : (2207, 7, 1)
# Shape of y_train after reshape : (2207, 1)

# %% [markdown]
# * Shape of X_train : 1134 x 50 x 1
# * That means we have 1134 rows, each row has 50 rows and 1 column
# * Lets check the first row: it has 50 rows (open prices of 49 days)

# %%
X_train[0]
# Out:
# array([[0.01479878],
#        [0.01562095],
#        [0.01546635],
#        [0.01361826],
#        [0.01259934],
#        [0.01435608],
#        [0.01181934]])

# %% [markdown]
# * Check the first item in y_train
# * It is the price of 50th day

# %%
y_train[0]
# Out:
# array([0.01089181])

# %% [markdown]
# <a id="6"></a>
# ## 6.Creating RNN model

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True, 
              input_shape = (X_train.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam", 
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train, y_train, epochs = 200, batch_size = 32)
# Out:
# Epoch 1/200
# 69/69 [==============================] - 4s 6ms/step - loss: 0.1990 - accuracy: 9.0621e-04
# Epoch 2/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 9.0621e-04
# Epoch 3/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 9.0621e-04
# Epoch 4/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 9.0621e-04
# Epoch 5/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 9.0621e-04
# Epoch 6/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 9.0621e-04
# Epoch 7/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 9.0621e-04
# Epoch 8/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 9.0621e-04
# Epoch 9/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 9.0621e-04
# Epoch 10/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 9.0621e-04
# Epoch 11/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 9.0621e-04
# Epoch 12/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 9.0621e-04
# Epoch 13/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 9.0621e-04
# Epoch 14/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 9.0621e-04
# Epoch 15/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 9.0621e-04
# Epoch 16/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 9.0621e-04
# Epoch 17/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 9.0621e-04
# Epoch 18/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 9.0621e-04
# Epoch 19/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 9.0621e-04
# Epoch 20/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 9.0621e-04
# Epoch 21/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 9.0621e-04
# Epoch 22/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 9.0621e-04
# Epoch 23/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 9.0621e-04
# Epoch 24/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 9.0621e-04
# Epoch 25/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 9.0621e-04
# Epoch 26/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 9.0621e-04
# Epoch 27/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 9.0621e-04
# Epoch 28/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 9.0621e-04
# Epoch 29/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 9.0621e-04
# Epoch 30/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 9.0621e-04
# Epoch 31/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 9.0621e-04
# Epoch 32/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 9.0621e-04
# Epoch 33/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 9.0621e-04
# Epoch 34/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 9.0621e-04
# Epoch 35/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 9.0621e-04
# Epoch 36/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 9.0621e-04
# Epoch 37/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 9.0621e-04
# Epoch 38/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 9.0621e-04
# Epoch 39/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 9.0621e-04
# Epoch 40/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 9.0621e-04
# Epoch 41/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 9.0621e-04
# Epoch 42/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 43/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 44/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 45/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 46/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 47/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 9.0621e-04
# Epoch 48/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 49/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 50/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 51/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 52/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 9.0621e-04
# Epoch 53/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 54/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 55/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 9.0621e-04
# Epoch 56/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 57/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 58/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 59/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 60/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 61/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 9.0621e-04
# Epoch 62/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 63/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 64/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 65/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 9.0621e-04
# Epoch 66/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 67/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 68/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 9.0621e-04
# Epoch 69/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 70/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 71/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.0768e-04 - accuracy: 9.0621e-04
# Epoch 72/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 73/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.8376e-04 - accuracy: 9.0621e-04
# Epoch 74/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.7301e-04 - accuracy: 9.0621e-04
# Epoch 75/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 76/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.6042e-04 - accuracy: 9.0621e-04
# Epoch 77/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.8482e-04 - accuracy: 9.0621e-04
# Epoch 78/200
# 69/69 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 79/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 80/200
# 69/69 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 9.0621e-04
# Epoch 81/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.3910e-04 - accuracy: 9.0621e-04
# Epoch 82/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7277e-04 - accuracy: 9.0621e-04
# Epoch 83/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6529e-04 - accuracy: 9.0621e-04
# Epoch 84/200
# 69/69 [==============================] - 0s 7ms/step - loss: 8.2444e-04 - accuracy: 9.0621e-04
# Epoch 85/200
# 69/69 [==============================] - 0s 7ms/step - loss: 9.6853e-04 - accuracy: 9.0621e-04
# Epoch 86/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7462e-04 - accuracy: 9.0621e-04
# Epoch 87/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8449e-04 - accuracy: 9.0621e-04
# Epoch 88/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.1830e-04 - accuracy: 9.0621e-04
# Epoch 89/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0750e-04 - accuracy: 9.0621e-04
# Epoch 90/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.9903e-04 - accuracy: 9.0621e-04
# Epoch 91/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.3336e-04 - accuracy: 9.0621e-04
# Epoch 92/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2514e-04 - accuracy: 9.0621e-04
# Epoch 93/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6263e-04 - accuracy: 9.0621e-04
# Epoch 94/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2421e-04 - accuracy: 9.0621e-04
# Epoch 95/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7671e-04 - accuracy: 9.0621e-04
# Epoch 96/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8381e-04 - accuracy: 9.0621e-04
# Epoch 97/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9847e-04 - accuracy: 9.0621e-04
# Epoch 98/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7835e-04 - accuracy: 9.0621e-04
# Epoch 99/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9969e-04 - accuracy: 9.0621e-04
# Epoch 100/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7984e-04 - accuracy: 9.0621e-04
# Epoch 101/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2626e-04 - accuracy: 9.0621e-04
# Epoch 102/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7679e-04 - accuracy: 9.0621e-04
# Epoch 103/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6845e-04 - accuracy: 9.0621e-04
# Epoch 104/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9501e-04 - accuracy: 9.0621e-04
# Epoch 105/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.4370e-04 - accuracy: 9.0621e-04
# Epoch 106/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9019e-04 - accuracy: 9.0621e-04
# Epoch 107/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5879e-04 - accuracy: 9.0621e-04
# Epoch 108/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.2114e-04 - accuracy: 9.0621e-04
# Epoch 109/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.0722e-04 - accuracy: 9.0621e-04
# Epoch 110/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.2593e-04 - accuracy: 9.0621e-04
# Epoch 111/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.7317e-04 - accuracy: 9.0621e-04
# Epoch 112/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9526e-04 - accuracy: 9.0621e-04
# Epoch 113/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5509e-04 - accuracy: 9.0621e-04
# Epoch 114/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.9928e-04 - accuracy: 9.0621e-04
# Epoch 115/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.6528e-04 - accuracy: 9.0621e-04
# Epoch 116/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.3151e-04 - accuracy: 9.0621e-04
# Epoch 117/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9216e-04 - accuracy: 9.0621e-04
# Epoch 118/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4937e-04 - accuracy: 9.0621e-04
# Epoch 119/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1457e-04 - accuracy: 9.0621e-04
# Epoch 120/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9797e-04 - accuracy: 9.0621e-04
# Epoch 121/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0804e-04 - accuracy: 9.0621e-04
# Epoch 122/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8649e-04 - accuracy: 9.0621e-04
# Epoch 123/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5559e-04 - accuracy: 9.0621e-04
# Epoch 124/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3613e-04 - accuracy: 9.0621e-04
# Epoch 125/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2506e-04 - accuracy: 9.0621e-04
# Epoch 126/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5869e-04 - accuracy: 9.0621e-04
# Epoch 127/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3637e-04 - accuracy: 9.0621e-04
# Epoch 128/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6662e-04 - accuracy: 9.0621e-04
# Epoch 129/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.8628e-04 - accuracy: 9.0621e-04
# Epoch 130/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2936e-04 - accuracy: 9.0621e-04
# Epoch 131/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.9986e-04 - accuracy: 9.0621e-04
# Epoch 132/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3759e-04 - accuracy: 9.0621e-04
# Epoch 133/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1251e-04 - accuracy: 9.0621e-04
# Epoch 134/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7773e-04 - accuracy: 9.0621e-04
# Epoch 135/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3159e-04 - accuracy: 9.0621e-04
# Epoch 136/200
# 69/69 [==============================] - 0s 6ms/step - loss: 9.1485e-04 - accuracy: 9.0621e-04
# Epoch 137/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6449e-04 - accuracy: 9.0621e-04
# Epoch 138/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.5087e-04 - accuracy: 9.0621e-04
# Epoch 139/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5065e-04 - accuracy: 9.0621e-04
# Epoch 140/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.5614e-04 - accuracy: 9.0621e-04
# Epoch 141/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1624e-04 - accuracy: 9.0621e-04
# Epoch 142/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8359e-04 - accuracy: 9.0621e-04
# Epoch 143/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5771e-04 - accuracy: 9.0621e-04
# Epoch 144/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0988e-04 - accuracy: 9.0621e-04
# Epoch 145/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.9528e-04 - accuracy: 9.0621e-04
# Epoch 146/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2477e-04 - accuracy: 9.0621e-04
# Epoch 147/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7889e-04 - accuracy: 9.0621e-04
# Epoch 148/200
# 69/69 [==============================] - 0s 7ms/step - loss: 8.2328e-04 - accuracy: 9.0621e-04
# Epoch 149/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7513e-04 - accuracy: 9.0621e-04
# Epoch 150/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.3885e-04 - accuracy: 9.0621e-04
# Epoch 151/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1748e-04 - accuracy: 9.0621e-04
# Epoch 152/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.6477e-04 - accuracy: 9.0621e-04
# Epoch 153/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3592e-04 - accuracy: 9.0621e-04
# Epoch 154/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5214e-04 - accuracy: 9.0621e-04
# Epoch 155/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1672e-04 - accuracy: 9.0621e-04
# Epoch 156/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5443e-04 - accuracy: 9.0621e-04
# Epoch 157/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1700e-04 - accuracy: 9.0621e-04
# Epoch 158/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2952e-04 - accuracy: 9.0621e-04
# Epoch 159/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8921e-04 - accuracy: 9.0621e-04
# Epoch 160/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.7196e-04 - accuracy: 9.0621e-04
# Epoch 161/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3983e-04 - accuracy: 9.0621e-04
# Epoch 162/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.5361e-04 - accuracy: 9.0621e-04
# Epoch 163/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.2119e-04 - accuracy: 9.0621e-04
# Epoch 164/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6309e-04 - accuracy: 9.0621e-04
# Epoch 165/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.5829e-04 - accuracy: 9.0621e-04
# Epoch 166/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6293e-04 - accuracy: 9.0621e-04
# Epoch 167/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4662e-04 - accuracy: 9.0621e-04
# Epoch 168/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5383e-04 - accuracy: 9.0621e-04
# Epoch 169/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.7177e-04 - accuracy: 9.0621e-04
# Epoch 170/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.6767e-04 - accuracy: 9.0621e-04
# Epoch 171/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.0135e-04 - accuracy: 9.0621e-04
# Epoch 172/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0444e-04 - accuracy: 9.0621e-04
# Epoch 173/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5692e-04 - accuracy: 9.0621e-04
# Epoch 174/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3400e-04 - accuracy: 9.0621e-04
# Epoch 175/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8764e-04 - accuracy: 9.0621e-04
# Epoch 176/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0092e-04 - accuracy: 9.0621e-04
# Epoch 177/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.2155e-04 - accuracy: 9.0621e-04
# Epoch 178/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.1397e-04 - accuracy: 9.0621e-04
# Epoch 179/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7969e-04 - accuracy: 9.0621e-04
# Epoch 180/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.8463e-04 - accuracy: 9.0621e-04
# Epoch 181/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.5574e-04 - accuracy: 9.0621e-04
# Epoch 182/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1575e-04 - accuracy: 9.0621e-04
# Epoch 183/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.4118e-04 - accuracy: 9.0621e-04
# Epoch 184/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5541e-04 - accuracy: 9.0621e-04
# Epoch 185/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3463e-04 - accuracy: 9.0621e-04
# Epoch 186/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.8195e-04 - accuracy: 9.0621e-04
# Epoch 187/200
# 69/69 [==============================] - 0s 6ms/step - loss: 8.1073e-04 - accuracy: 9.0621e-04
# Epoch 188/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0816e-04 - accuracy: 9.0621e-04
# Epoch 189/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6317e-04 - accuracy: 9.0621e-04
# Epoch 190/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.5157e-04 - accuracy: 9.0621e-04
# Epoch 191/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.0257e-04 - accuracy: 9.0621e-04
# Epoch 192/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6601e-04 - accuracy: 9.0621e-04
# Epoch 193/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.7136e-04 - accuracy: 9.0621e-04
# Epoch 194/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.4466e-04 - accuracy: 9.0621e-04
# Epoch 195/200
# 69/69 [==============================] - 0s 7ms/step - loss: 6.8263e-04 - accuracy: 9.0621e-04
# Epoch 196/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.5182e-04 - accuracy: 9.0621e-04
# Epoch 197/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.3480e-04 - accuracy: 9.0621e-04
# Epoch 198/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.3790e-04 - accuracy: 9.0621e-04
# Epoch 199/200
# 69/69 [==============================] - 0s 6ms/step - loss: 7.3137e-04 - accuracy: 9.0621e-04
# Epoch 200/200
# 69/69 [==============================] - 0s 6ms/step - loss: 6.6220e-04 - accuracy: 9.0621e-04

# %% [markdown]
# <a id="7"></a>
# ## 7.Evaluating Model

# %%
# Losses
history.history["loss"]
# Out:
# [0.19895921647548676,
#  0.06545562297105789,
#  0.03650253638625145,
#  0.02761238068342209,
#  0.018841583281755447,
#  0.015058865770697594,
#  0.012213176116347313,
#  0.010725744068622589,
#  0.010156732983887196,
#  0.008168227970600128,
#  0.007392968982458115,
#  0.006166602484881878,
#  0.006141355726867914,
#  0.005225321743637323,
#  0.005026872269809246,
#  0.004234244581311941,
#  0.003985118120908737,
#  0.003948022611439228,
#  0.0034992066211998463,
#  0.003465198678895831,
#  0.003259431105107069,
#  0.0031021316535770893,
#  0.003072716062888503,
#  0.0027674161829054356,
#  0.0025266415905207396,
#  0.002788975602015853,
#  0.0026265892665833235,
#  0.002432588953524828,
#  0.0021207635290920734,
#  0.002106851665303111,
#  0.002206524834036827,
#  0.0020205508917570114,
#  0.0020779408514499664,
#  0.0018896493129432201,
#  0.00209679058752954,
#  0.002020939253270626,
#  0.001831970177590847,
#  0.0017473279731348157,
#  0.0016410788521170616,
#  0.0016163955442607403,
#  0.0015849678311496973,
#  0.00149932608474046,
#  0.001425701892003417,
#  0.001415048143826425,
#  0.0013999796938151121,
#  0.0015363463899120688,
#  0.0015932086389511824,
#  0.0013475907035171986,
#  0.001362073002383113,
#  0.0013388028601184487,
#  0.0015036043478175998,
#  0.001390827470459044,
#  0.0013136706547811627,
#  0.0015036285622045398,
#  0.0014947487507015467,
#  0.0012353828642517328,
#  0.0011630431981757283,
#  0.0010992258321493864,
#  0.0011489008320495486,
#  0.0011953858193010092,
#  0.0012901582522317767,
#  0.0010660288389772177,
#  0.0010762802558019757,
#  0.0011442666873335838,
#  0.0011703737545758486,
#  0.001028437982313335,
#  0.0010888504330068827,
#  0.0010899370536208153,
#  0.0010156534845009446,
#  0.001015390269458294,
#  0.0009076758287847042,
#  0.0010376087157055736,
#  0.0009837589459493756,
#  0.0009730060701258481,
#  0.0010099053615704179,
#  0.0009604202350601554,
#  0.0009848170448094606,
#  0.0010026547824963927,
#  0.001017211121506989,
#  0.0010364125482738018,
#  0.0009390997583977878,
#  0.0008727703243494034,
#  0.0008652948890812695,
#  0.000824441434815526,
#  0.0009685325203463435,
#  0.0008746228995732963,
#  0.0007844903157092631,
#  0.0009183017536997795,
#  0.000707500206772238,
#  0.0009990261169150472,
#  0.0008333598379977047,
#  0.0007251414936035872,
#  0.0008626251365058124,
#  0.0008242079638876021,
#  0.0007767134229652584,
#  0.0007838120800442994,
#  0.0007984692929312587,
#  0.0007783506298437715,
#  0.0007996915373951197,
#  0.000879839644767344,
#  0.0008262646733783185,
#  0.0007767879869788885,
#  0.0007684548036195338,
#  0.0007950145518407226,
#  0.0008436987991444767,
#  0.000790190533734858,
#  0.0008587897755205631,
#  0.0009211392025463283,
#  0.0009072204120457172,
#  0.0009259262587875128,
#  0.0008731693378649652,
#  0.000795255764387548,
#  0.0007550888694822788,
#  0.0008992751245386899,
#  0.0009652795852161944,
#  0.0008315106388181448,
#  0.0007921558571979403,
#  0.0007493673474527895,
#  0.0007145678391680121,
#  0.0007979650981724262,
#  0.0007080420036800206,
#  0.0007864896906539798,
#  0.0007555879419669509,
#  0.0007361259195022285,
#  0.0007250556373037398,
#  0.0007586931460537016,
#  0.0007363740005530417,
#  0.000766623008530587,
#  0.0008862766553647816,
#  0.0007293602102436125,
#  0.0006998564349487424,
#  0.0007375861750915647,
#  0.0007125132251530886,
#  0.0007777261198498309,
#  0.00073158775921911,
#  0.0009148512035608292,
#  0.0006644914392381907,
#  0.0006508713122457266,
#  0.0007506536785513163,
#  0.0008561422000639141,
#  0.0007162418914958835,
#  0.000683590245898813,
#  0.0007577068172395229,
#  0.000709882122464478,
#  0.0007952767773531377,
#  0.0008247704245150089,
#  0.0007788906223140657,
#  0.0008232752443291247,
#  0.0007751303492113948,
#  0.0008388544083572924,
#  0.0008174767135642469,
#  0.0008647735812701285,
#  0.0007359225419349968,
#  0.0007521419902332127,
#  0.0007167193107306957,
#  0.0007544329855591059,
#  0.0007169978343881667,
#  0.0007295227260328829,
#  0.0006892071105539799,
#  0.0006719598895870149,
#  0.0007398311281576753,
#  0.000653609458822757,
#  0.0008211859967559576,
#  0.0007630856707692146,
#  0.0006582893547601998,
#  0.000662926584482193,
#  0.0007466230890713632,
#  0.0007538276840932667,
#  0.0006717705982737243,
#  0.0007676703971810639,
#  0.0008013499318622053,
#  0.0007044358062557876,
#  0.0007569216541014612,
#  0.0007339973817579448,
#  0.0006876425468362868,
#  0.0007009184919297695,
#  0.0007215452496893704,
#  0.0007139683002606034,
#  0.0007796858553774655,
#  0.0006846346659585834,
#  0.0006557365995831788,
#  0.0008157484699040651,
#  0.0007411813130602241,
#  0.0007554106996394694,
#  0.000734630215447396,
#  0.0007819511229172349,
#  0.0008107259054668248,
#  0.0007081597577780485,
#  0.0006631701835431159,
#  0.00065156928030774,
#  0.0007025707745924592,
#  0.0006660110084339976,
#  0.0007713563973084092,
#  0.0006446643965318799,
#  0.0006826262106187642,
#  0.0007518183556385338,
#  0.0006348033784888685,
#  0.0006378993857651949,
#  0.0007313652895390987,
#  0.0006621982320211828]

# %%
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %% [markdown]
# ## Model predictions for train data

# %%
y_pred = regressor.predict(X_train)  # predictions
y_pred = scaler.inverse_transform(y_pred) # scaling back from 0-1 to original
y_pred.shape
# Out:
# 69/69 [==============================] - 1s 3ms/step
# (2207, 1)

# %%
y_train = scaler.inverse_transform(y_train) # scaling back from 0-1 to original
y_train.shape
# Out:
# (2207, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred, color = "b", label = "y_pred" )
plt.plot(y_train, color = "g", label = "y_train")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Predictions with input X_train vs y_train")
plt.legend()
plt.show()

# %% [markdown]
# <a id="8"></a>
# ## 8.Creating Test Dataset from Validation Data

# %% [markdown]
# ### Converting array and scaling

# %%
dataset_validation = validation_data.Open.values  # getting "open" column and converting to array
dataset_validation = np.reshape(dataset_validation, (-1,1))  # converting 1D to 2D array
scaled_dataset_validation =  scaler.fit_transform(dataset_validation)  # scaling open values to between 0 and 1
print("Shape of scaled validation dataset :",scaled_dataset_validation.shape)
# Out:
# Shape of scaled validation dataset : (553, 1)

# %% [markdown]
# ### Creating X_test and y_test

# %%
# Creating X_test and y_test
X_test = []
y_test = []

for i in range(time_step, length_validation):
    X_test.append(scaled_dataset_validation[i-time_step:i,0])
    y_test.append(scaled_dataset_validation[i,0])

# %% [markdown]
# ### Converting to array

# %%
# Converting to array
X_test, y_test = np.array(X_test), np.array(y_test)

# %%
print("Shape of X_test before reshape :",X_test.shape)
print("Shape of y_test before reshape :",y_test.shape)
# Out:
# Shape of X_test before reshape : (546, 7)
# Shape of y_test before reshape : (546,)

# %% [markdown]
# ### Reshape

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))  # reshape to 3D array
y_test = np.reshape(y_test, (-1,1))  # reshape to 2D array

# %%
print("Shape of X_test after reshape :",X_test.shape)
print("Shape of y_test after reshape :",y_test.shape)
# Out:
# Shape of X_test after reshape : (546, 7, 1)
# Shape of y_test after reshape : (546, 1)

# %% [markdown]
# <a id="9"></a>
# ## 9.Evaluating with Validation Data

# %%
# predictions with X_test data
y_pred_of_test = regressor.predict(X_test)
# scaling back from 0-1 to original
y_pred_of_test = scaler.inverse_transform(y_pred_of_test) 
print("Shape of y_pred_of_test :",y_pred_of_test.shape)
# Out:
# 18/18 [==============================] - 0s 3ms/step
# Shape of y_pred_of_test : (546, 1)

# %%
# visualisation
plt.figure(figsize = (30,10))
plt.plot(y_pred_of_test, label = "y_pred_of_test", c = "orange")
plt.plot(scaler.inverse_transform(y_test), label = "y_test", c = "g")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Prediction with input X_test vs y_test")
plt.legend()
plt.show()

# %%
mae = np.mean(np.abs(scaler.inverse_transform(y_test) - y_pred_of_test ))
print(mae)
rmse = np.sqrt(np.mean((scaler.inverse_transform(y_test) - y_pred_of_test) ** 2))
print(rmse)
#tính độ chính xác của dự báo
mape = np.mean(np.abs((scaler.inverse_transform(y_test) - y_pred_of_test )/ scaler.inverse_transform(y_test))) *100
print(mape)
# Out:
# 1.7732524648768568
# 2.5659594045131393
# 2.329478949153353

# %%
# Visualisation
plt.subplots(figsize =(30,12))
plt.plot(train_data.Date, train_data.Open, label = "train_data", color = "b")
plt.plot(validation_data.Date, validation_data.Open, label = "validation_data", color = "g")
plt.plot(train_data.Date.iloc[time_step:], y_pred, label = "y_pred", color = "r")
plt.plot(validation_data.Date.iloc[time_step:], y_pred_of_test, label = "y_pred_of_test", color = "orange")
plt.xlabel("Days")
plt.ylabel("Open price")
plt.title("Simple RNN model, Train-Validation-Prediction")
plt.legend()
plt.show()
