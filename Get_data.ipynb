# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
stock = yf.download('MSFT', 
                      start='2010-01-01', 
                      end='2020-12-30', 
                      interval="1d",
                      progress=False,
)
stock.shape
# Out:
# (2767, 6)

# %%
stock['Adj Close'].plot(legend=True,figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04  30.620001  31.100000  30.590000  30.950001  23.431597  38409100
# 2010-01-05  30.850000  31.100000  30.639999  30.959999  23.439156  49749600
# 2010-01-06  30.879999  31.080000  30.520000  30.770000  23.295315  58182400
# 2010-01-07  30.629999  30.700001  30.190001  30.450001  23.053057  50559700
# 2010-01-08  30.280001  30.879999  30.240000  30.660000  23.212034  51197400

# %%
print("final_df shape: ",stock.shape)
stock.to_csv('MSFT_raw_initial_df.csv')
# Out:
# final_df shape:  (2767, 6)

# %%
print(final_df.shape)
final_df.head(3)
# Out:
# (0, 0)
# Empty DataFrame
# Columns: []
# Index: []
